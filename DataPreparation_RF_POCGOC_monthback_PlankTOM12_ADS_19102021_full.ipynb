# %%
#preparation of data in format requiered for the ML use

# %%
import pandas as pd
import numpy as np

# %%
def MLD_averages_1(df, df_inMLD_test):
    df_inMLD = df.loc[df['depth'] <= df['MLD']]
    df_inMLD_test = df_inMLD.groupby(['coordinates','year','month']).mean().reset_index()

    df_inMLD_test.rename(columns={"Temp": "Temp_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"Temp_back": "Temp_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"O2": "O2_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"O2_back": "O2_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"NO3": "NO3_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"NO3_back": "NO3_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PO4": "PO4_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PO4_back": "PO4_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"Si": "Si_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"Si_back": "Si_back_mean"}, inplace=True)    
    df_inMLD_test.rename(columns={"CHL": "CHL_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"CHL_back": "CHL_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"BAC": "BAC_mean"}, inplace=True)   
    df_inMLD_test.rename(columns={"BAC_back": "BAC_back_mean"}, inplace=True) 
    df_inMLD_test.rename(columns={"MES": "MES_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"MES_back": "MES_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PTE": "PTE_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PTE_back": "PTE_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"DIA": "DIA_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"DIA_back": "DIA_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"COC": "COC_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"COC_back": "COC_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PIC": "PIC_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PIC_back": "PIC_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PHA": "PHA_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PHA_back": "PHA_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"GEL": "GEL_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"GEL_back": "GEL_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PRO": "PRO_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PRO_back": "PRO_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"MAC": "MAC_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"MAC_back": "MAC_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"MIX": "MIX_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"MIX_back": "MIX_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"FIX": "FIX_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"FIX_back": "FIX_back_mean"}, inplace=True)
    
    return df_inMLD_test

# %%
def MLD_averages_2(df,df_inMLD_test):
    df_inMLD = df.loc[df['depth'] <= df['MLD']]
    df_inMLD_test = df_inMLD.groupby(['coordinates','year','month']).mean().reset_index()

    df_inMLD_test.rename(columns={"Temp": "Temp_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"O2": "O2_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"NO3": "NO3_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PO4": "PO4_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"Si": "Si_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"CHL": "CHL_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"CHL_back": "CHL_back_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"BAC": "BAC_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"MES": "MES_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PTE": "PTE_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"DIA": "DIA_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"COC": "COC_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PIC": "PIC_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PHA": "PHA_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"GEL": "GEL_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"PRO": "PRO_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"MAC": "MAC_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"MIX": "MIX_mean"}, inplace=True)
    df_inMLD_test.rename(columns={"FIX": "FIX_mean"}, inplace=True)
                   
    return df_inMLD_test

# %%
def unit_rescale_1(df):
    df['POC'] = df['POC'] * 1000000.
    df['GOC'] = df['GOC'] * 1000000.

    df['BAC'] = df['BAC'] * 1000000.
    df['MES'] = df['MES'] * 1000000.
    df['PTE'] = df['PTE'] * 1000000.
    df['DIA'] = df['DIA'] * 1000000.
    df['COC'] = df['COC'] * 1000000.
    df['PIC'] = df['PIC'] * 1000000.
    df['PHA'] = df['PHA'] * 1000000.
    df['GEL'] = df['GEL'] * 1000000.
    df['PRO'] = df['PRO'] * 1000000.
    df['MAC'] = df['MAC'] * 1000000.
    df['MIX'] = df['MIX'] * 1000000.
    df['FIX'] = df['FIX'] * 1000000.

    df['BAC_mean'] = df['BAC_mean'] * 1000000.
    df['MES_mean'] = df['MES_mean'] * 1000000.
    df['PTE_mean'] = df['PTE_mean'] * 1000000.
    df['DIA_mean'] = df['DIA_mean'] * 1000000.
    df['COC_mean'] = df['COC_mean'] * 1000000.
    df['PIC_mean'] = df['PIC_mean'] * 1000000.
    df['PHA_mean'] = df['PHA_mean'] * 1000000.
    df['GEL_mean'] = df['GEL_mean'] * 1000000.
    df['PRO_mean'] = df['PRO_mean'] * 1000000.
    df['MAC_mean'] = df['MAC_mean'] * 1000000.
    df['MIX_mean'] = df['MIX_mean'] * 1000000.
    df['FIX_mean'] = df['FIX_mean'] * 1000000.

    df['BAC_back'] = df['BAC_back'] * 1000000.
    df['MES_back'] = df['MES_back'] * 1000000.
    df['PTE_back'] = df['PTE_back'] * 1000000.
    df['DIA_back'] = df['DIA_back'] * 1000000.
    df['COC_back'] = df['COC_back'] * 1000000.
    df['PIC_back'] = df['PIC_back'] * 1000000.
    df['PHA_back'] = df['PHA_back'] * 1000000.
    df['GEL_back'] = df['GEL_back'] * 1000000.
    df['PRO_back'] = df['PRO_back'] * 1000000.
    df['MAC_back'] = df['MAC_back'] * 1000000.
    df['MIX_back'] = df['MIX_back'] * 1000000.
    df['FIX_back'] = df['FIX_back'] * 1000000.

    df['BAC_back_mean'] = df['BAC_back_mean'] * 1000000.
    df['MES_back_mean'] = df['MES_back_mean'] * 1000000.
    df['PTE_back_mean'] = df['PTE_back_mean'] * 1000000.
    df['DIA_back_mean'] = df['DIA_back_mean'] * 1000000.
    df['COC_back_mean'] = df['COC_back_mean'] * 1000000.
    df['PIC_back_mean'] = df['PIC_back_mean'] * 1000000.
    df['PHA_back_mean'] = df['PHA_back_mean'] * 1000000.
    df['GEL_back_mean'] = df['GEL_back_mean'] * 1000000.
    df['PRO_back_mean'] = df['PRO_back_mean'] * 1000000.
    df['MAC_back_mean'] = df['MAC_back_mean'] * 1000000.
    df['MIX_back_mean'] = df['MIX_back_mean'] * 1000000.
    df['FIX_back_mean'] = df['FIX_back_mean'] * 1000000.
    
    df['CHL'] = df['CHL'] * 1000000.
    df['CHL_mean'] = df['CHL_mean'] * 1000000.
    df['CHL_back'] = df['CHL_back'] * 1000000.
    df['CHL_back_mean'] = df['CHL_back_mean'] * 1000000.

    df['Big_zoopl'] = df['GEL'] + df['MES'] + df['MAC']
    df['Big_zoopl2'] = df['GEL'] + df['MES'] + df['MAC'] + df['PTE']
    
    return df

# %%
def unit_rescale_2(df):
    df['POC'] = df['POC'] * 1000000.
    df['GOC'] = df['GOC'] * 1000000.

    df['BAC'] = df['BAC'] * 1000000.
    df['MES'] = df['MES'] * 1000000.
    df['PTE'] = df['PTE'] * 1000000.
    df['DIA'] = df['DIA'] * 1000000.
    df['COC'] = df['COC'] * 1000000.
    df['PIC'] = df['PIC'] * 1000000.
    df['PHA'] = df['PHA'] * 1000000.
    df['GEL'] = df['GEL'] * 1000000.
    df['PRO'] = df['PRO'] * 1000000.
    df['MAC'] = df['MAC'] * 1000000.
    df['MIX'] = df['MIX'] * 1000000.
    df['FIX'] = df['FIX'] * 1000000.

    df['BAC_mean'] = df['BAC_mean'] * 1000000.
    df['MES_mean'] = df['MES_mean'] * 1000000.
    df['PTE_mean'] = df['PTE_mean'] * 1000000.
    df['DIA_mean'] = df['DIA_mean'] * 1000000.
    df['COC_mean'] = df['COC_mean'] * 1000000.
    df['PIC_mean'] = df['PIC_mean'] * 1000000.
    df['PHA_mean'] = df['PHA_mean'] * 1000000.
    df['GEL_mean'] = df['GEL_mean'] * 1000000.
    df['PRO_mean'] = df['PRO_mean'] * 1000000.
    df['MAC_mean'] = df['MAC_mean'] * 1000000.
    df['MIX_mean'] = df['MIX_mean'] * 1000000.
    df['FIX_mean'] = df['FIX_mean'] * 1000000.
    
    df['CHL'] = df['CHL'] * 1000000.
    df['CHL_mean'] = df['CHL_mean'] * 1000000.
    df['CHL_back'] = df['CHL_back'] * 1000000.
    df['CHL_back_mean'] = df['CHL_back_mean'] * 1000000.

    df['Big_zoopl'] = df['GEL'] + df['MES'] + df['MAC']
    df['Big_zoopl2'] = df['GEL'] + df['MES'] + df['MAC'] + df['PTE']
    
    return df

# %%
r_filenameTSV1 = 'Data_ML_PlankTOM_All_PFTCHL_bottom_13122021.csv'
All_Data_tot_Pl = pd.read_csv(r_filenameTSV1)

r_filenameTSV1 = 'Data_ML_PlankTOM_RKiko_PFT_CHLback_bottom_13122021.csv'
All_Data_tot_RK = pd.read_csv(r_filenameTSV1)

r_filenameTSV1 = 'Data_ML_PlankTOM_All_PFTCHL_NoNAN_Validation_18102021.csv'
All_Data_tot_IV_Pl = pd.read_csv(r_filenameTSV1)

# %%
r_filenameTSV1 = 'Data_from_PlankTOM/Data_ML_PlankTOM_Reconstr_2009_04102021.csv'
PlankTOM_2009 = pd.read_csv(r_filenameTSV1)

r_filenameTSV1 = 'Data_from_PlankTOM/Data_ML_PlankTOM_Reconstr_2010_04102021.csv'
PlankTOM_2010 = pd.read_csv(r_filenameTSV1)

r_filenameTSV1 = 'Data_from_PlankTOM/Data_ML_PlankTOM_Reconstr_2011_04102021.csv'
PlankTOM_2011 = pd.read_csv(r_filenameTSV1)

r_filenameTSV1 = 'Data_from_PlankTOM/Data_ML_PlankTOM_Reconstr_2012_04102021.csv'
PlankTOM_2012 = pd.read_csv(r_filenameTSV1)

r_filenameTSV1 = 'Data_from_PlankTOM/Data_ML_PlankTOM_Reconstr_2013_04102021.csv'
PlankTOM_2013 = pd.read_csv(r_filenameTSV1)

# %%
All_Data_tot_Pl['coordinates'] = list(zip(All_Data_tot_Pl.lat_Pl, All_Data_tot_Pl.lon_Pl))
All_Data_tot_IV_Pl['coordinates'] = list(zip(All_Data_tot_IV_Pl.lat_Pl, All_Data_tot_IV_Pl.lon_Pl))
All_Data_tot_RK['coordinates'] = list(zip(All_Data_tot_RK.lat_Pl, All_Data_tot_RK.lon_Pl))

# %%
PlankTOM_2009['coordinates'] = list(zip(PlankTOM_2009.lat_Pl, PlankTOM_2009.lon_Pl))
PlankTOM_2010['coordinates'] = list(zip(PlankTOM_2010.lat_Pl, PlankTOM_2010.lon_Pl))
PlankTOM_2011['coordinates'] = list(zip(PlankTOM_2011.lat_Pl, PlankTOM_2011.lon_Pl))
PlankTOM_2012['coordinates'] = list(zip(PlankTOM_2012.lat_Pl, PlankTOM_2012.lon_Pl))
PlankTOM_2013['coordinates'] = list(zip(PlankTOM_2013.lat_Pl, PlankTOM_2013.lon_Pl))

# %%
#estimation of varibales averaged over mixed-layer depth (MLD) for Tara data
MLD_averages_1(All_Data_tot_Pl, All_Data_inMLD_test)

All_Data_inMLD_test_extr = All_Data_inMLD_test[['coordinates', 'year', 'month', 'Temp_mean', 'O2_mean','NO3_mean',\
                                                'PO4_mean', 'Si_mean', 'CHL_mean', 'CHL_back_mean', 'BAC_mean',\
                                                'MES_mean', 'PTE_mean', 'DIA_mean','COC_mean', 'PIC_mean', 'PHA_mean',\
                                                'GEL_mean', 'PRO_mean','MAC_mean', 'MIX_mean', 'FIX_mean',\
                                                'Temp_back_mean', 'O2_back_mean','NO3_back_mean',\
                                                'PO4_back_mean', 'Si_back_mean', 'BAC_back_mean',\
                                                'MES_back_mean', 'PTE_back_mean', 'DIA_back_mean','COC_back_mean',\
                                                'PIC_back_mean', 'PHA_back_mean',\
                                                'GEL_back_mean', 'PRO_back_mean','MAC_back_mean',\
                                                'MIX_back_mean', 'FIX_back_mean']]

#merge original Tara data with the averages over MLD
All_Data_tot_Pl_mr = pd.merge(All_Data_tot_Pl,All_Data_inMLD_test_extr, on=['coordinates','year','month'], how = 'left')

# %%
#estimation of varibales averaged over mixed-layer depth (MLD) for test data (outside of UVP5 regions)
MLD_averages_1(All_Data_tot_IV_Pl, All_Data_inMLD_IV_test)

All_Data_inMLD_IV_test_extr = All_Data_inMLD_IV_test[['coordinates', 'year', 'month', 'Temp_mean', 'O2_mean',\
                                                      'NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean', 'CHL_back_mean',\
                                                      'BAC_mean', 'MES_mean', 'PTE_mean', 'DIA_mean','COC_mean',\
                                                      'PIC_mean', 'PHA_mean', 'GEL_mean', 'PRO_mean','MAC_mean',\
                                                      'MIX_mean', 'FIX_mean','Temp_back_mean', 'O2_back_mean',\
                                                      'NO3_back_mean', 'PO4_back_mean', 'Si_back_mean',\
                                                      'BAC_back_mean', 'MES_back_mean', 'PTE_back_mean',\
                                                      'DIA_back_mean','COC_back_mean',\
                                                      'PIC_back_mean', 'PHA_back_mean', 'GEL_back_mean',\
                                                      'PRO_back_mean','MAC_back_mean',\
                                                      'MIX_back_mean', 'FIX_back_mean']]

#merge original test data with the averages over MLD
All_Data_tot_IV_Pl_mr = pd.merge(All_Data_tot_IV_Pl,All_Data_inMLD_IV_test_extr, on=['coordinates','year','month'], how = 'left')

# %%
#estimation of varibales averaged over mixed-layer depth (MLD) for UVP5 data
MLD_averages_1(All_Data_tot_RK, All_Data_tot_RK_inMLD_test)

All_Data_tot_RK_inMLD_test_extr = All_Data_tot_RK_inMLD_test[['coordinates', 'year', 'month', 'Temp_mean', 'O2_mean',\
                                                              'NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean',\
                                                              'CHL_back_mean', 'BAC_mean', 'MES_mean', 'PTE_mean',\
                                                              'DIA_mean','COC_mean', 'PIC_mean', 'PHA_mean',\
                                                              'GEL_mean', 'PRO_mean','MAC_mean', 'MIX_mean',\
                                                              'FIX_mean','Temp_back_mean', 'O2_back_mean',\
                                                              'NO3_back_mean', 'PO4_back_mean', 'Si_back_mean',\
                                                              'BAC_back_mean', 'MES_back_mean', 'PTE_back_mean',\
                                                              'DIA_back_mean','COC_back_mean', 'PIC_back_mean',\
                                                              'PHA_back_mean',\
                                                              'GEL_back_mean', 'PRO_back_mean','MAC_back_mean',\
                                                              'MIX_back_mean','FIX_back_mean']]

#merge original UVP5 data with the averages over MLD
All_Data_tot_RK_mr = pd.merge(All_Data_tot_RK,All_Data_tot_RK_inMLD_test_extr, on=['coordinates','year','month'], how = 'left')

# %%
#estimation of varibales averaged over mixed-layer depth (MLD) for PlankTOM12 2009
MLD_averages_2(PlankTOM_2009,PlankTOM_2009_inMLD_test)

PlankTOM_2009_inMLD_test_extr = PlankTOM_2009_inMLD_test[['coordinates', 'year', 'month', 'Temp_mean', 'O2_mean',\
                                                          'NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean', \
                                                          'CHL_back_mean', 'BAC_mean', 'MES_mean', 'PTE_mean',\
                                                          'DIA_mean','COC_mean', 'PIC_mean', 'PHA_mean', 'GEL_mean',\
                                                          'PRO_mean','MAC_mean', 'MIX_mean', 'FIX_mean']]

PlankTOM_2009_mr = pd.merge(PlankTOM_2009,PlankTOM_2009_inMLD_test_extr, on=['coordinates','year','month'], how = 'left')

# %%
#estimation of varibales averaged over mixed-layer depth (MLD) for PlankTOM12 2010
MLD_averages_2(PlankTOM_2010,PlankTOM_2010_inMLD_test)

PlankTOM_2010_inMLD_test_extr = PlankTOM_2010_inMLD_test[['coordinates', 'year', 'month', 'Temp_mean', 'O2_mean',\
                                                          'NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean',\
                                                          'CHL_back_mean', 'BAC_mean', 'MES_mean', 'PTE_mean',\
                                                          'DIA_mean','COC_mean', 'PIC_mean', 'PHA_mean', 'GEL_mean',\
                                                          'PRO_mean','MAC_mean', 'MIX_mean', 'FIX_mean']]

PlankTOM_2010_mr = pd.merge(PlankTOM_2010,PlankTOM_2010_inMLD_test_extr, on=['coordinates','year','month'], how = 'left')

# %%
#estimation of varibales averaged over mixed-layer depth (MLD) for PlankTOM12 2011
MLD_averages_2(PlankTOM_2011,PlankTOM_2011_inMLD_test)

PlankTOM_2011_inMLD_test_extr = PlankTOM_2011_inMLD_test[['coordinates', 'year', 'month', 'Temp_mean', 'O2_mean',\
                                                          'NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean',\
                                                          'CHL_back_mean', 'BAC_mean', 'MES_mean', 'PTE_mean', \
                                                          'DIA_mean','COC_mean', 'PIC_mean', 'PHA_mean', 'GEL_mean',\
                                                          'PRO_mean','MAC_mean', 'MIX_mean', 'FIX_mean']]

PlankTOM_2011_mr = pd.merge(PlankTOM_2011,PlankTOM_2011_inMLD_test_extr, on=['coordinates','year','month'], how = 'left')

# %%
#estimation of varibales averaged over mixed-layer depth (MLD) for PlankTOM12 2012
MLD_averages_2(PlankTOM_2012,PlankTOM_2012_inMLD_test)

PlankTOM_2012_inMLD_test_extr = PlankTOM_2012_inMLD_test[['coordinates', 'year', 'month', 'Temp_mean', 'O2_mean',\
                                                          'NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean',\
                                                          'CHL_back_mean', 'BAC_mean', 'MES_mean', 'PTE_mean', \
                                                          'DIA_mean','COC_mean', 'PIC_mean', 'PHA_mean', 'GEL_mean',\
                                                          'PRO_mean','MAC_mean', 'MIX_mean', 'FIX_mean']]

PlankTOM_2012_mr = pd.merge(PlankTOM_2012,PlankTOM_2012_inMLD_test_extr, on=['coordinates','year','month'], how = 'left')

# %%
#estimation of varibales averaged over mixed-layer depth (MLD) for PlankTOM12 2013
MLD_averages_2(PlankTOM_2013,PlankTOM_2013_inMLD_test)

PlankTOM_2013_inMLD_test_extr = PlankTOM_2013_inMLD_test[['coordinates', 'year', 'month', 'Temp_mean', 'O2_mean',\
                                                          'NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean',\
                                                          'CHL_back_mean', 'BAC_mean', 'MES_mean', 'PTE_mean', \
                                                          'DIA_mean','COC_mean', 'PIC_mean', 'PHA_mean', 'GEL_mean',\
                                                          'PRO_mean','MAC_mean', 'MIX_mean', 'FIX_mean']]

PlankTOM_2013_mr = pd.merge(PlankTOM_2013,PlankTOM_2013_inMLD_test_extr, on=['coordinates','year','month'], how = 'left')

# %%
All_Data_Pl = All_Data_tot_Pl.loc[All_Data_tot_Pl['depth'] < 1600.]
All_Data_IV_Pl = All_Data_tot_IV_Pl.loc[All_Data_tot_IV_Pl['depth'] < 1600.]
All_Data_RK = All_Data_tot_RK.loc[All_Data_tot_RK['depth'] < 1600.]

# %%
#rescale variables
unit_rescale_1(All_Data_tot_Pl_mr)
unit_rescale_1(All_Data_tot_IV_Pl_mr)
unit_rescale_1(All_Data_tot_RK_mr)

# %%
unit_rescale_2(PlankTOM_2009_mr)
unit_rescale_2(PlankTOM_2010_mr)
unit_rescale_2(PlankTOM_2011_mr)
unit_rescale_2(PlankTOM_2012_mr)
unit_rescale_2(PlankTOM_2013_mr)

# %%
#remove large values of large particulate organic carbon (GOC)
Large_Data = All_Data_tot_Pl_mr.loc[All_Data_tot_Pl_mr['GOC'] > 2.]
All_Data_tot_Pl_mr = All_Data_tot_Pl_mr.drop(Large_Data.index.to_numpy()).reset_index()

Large_Data_IV = All_Data_tot_IV_Pl_mr.loc[All_Data_tot_IV_Pl_mr['GOC'] > 2.]
All_Data_tot_IV_Pl_mr = All_Data_tot_IV_Pl_mr.drop(Large_Data_IV.index.to_numpy()).reset_index()

Large_Data_RK = All_Data_tot_RK_mr.loc[All_Data_tot_RK_mr['GOC'] > 2.]
All_Data_tot_RK_mr = All_Data_tot_RK_mr.drop(Large_Data_RK.index.to_numpy()).reset_index()

# %%
Large_Data_2009 = PlankTOM_2009_mr.loc[PlankTOM_2009_mr['GOC'] > 2.]
PlankTOM_2009_mr = PlankTOM_2009_mr.drop(Large_Data_2009.index.to_numpy()).reset_index()

Large_Data_2010 = PlankTOM_2010_mr.loc[PlankTOM_2010_mr['GOC'] > 2.]
PlankTOM_2010_mr = PlankTOM_2010_mr.drop(Large_Data_2010.index.to_numpy()).reset_index()

Large_Data_2011 = PlankTOM_2011_mr.loc[PlankTOM_2011_mr['GOC'] > 2.]
PlankTOM_2011_mr = PlankTOM_2011_mr.drop(Large_Data_2011.index.to_numpy()).reset_index()

Large_Data_2012 = PlankTOM_2012_mr.loc[PlankTOM_2012_mr['GOC'] > 2.]
PlankTOM_2012_mr = PlankTOM_2012_mr.drop(Large_Data_2012.index.to_numpy()).reset_index()

Large_Data_2013 = PlankTOM_2013_mr.loc[PlankTOM_2013_mr['GOC'] > 2.]
PlankTOM_2013_mr = PlankTOM_2013_mr.drop(Large_Data_2013.index.to_numpy()).reset_index()

# %%
#remove depth that is under PlankTOM12 bathymetry
All_Data_Pl_new = All_Data_tot_Pl_mr.loc[All_Data_tot_Pl_mr['depth'] < All_Data_tot_Pl_mr['bottom']]

All_Data_IV_Pl_new = All_Data_tot_IV_Pl_mr.loc[All_Data_tot_IV_Pl_mr['depth'] < All_Data_tot_IV_Pl_mr['bottom']]

All_Data_RK_new = All_Data_tot_RK_mr.loc[All_Data_tot_RK_mr['depth'] < All_Data_tot_RK_mr['bottom']]

# %%
PlankTOM_2009_Rec_new = PlankTOM_2009_mr.loc[PlankTOM_2009_mr['depth'] < PlankTOM_2009_mr['bottom']]

PlankTOM_2010_Rec_new = PlankTOM_2010_mr.loc[PlankTOM_2010_mr['depth'] < PlankTOM_2010_mr['bottom']]

PlankTOM_2011_Rec_new = PlankTOM_2011_mr.loc[PlankTOM_2011_mr['depth'] < PlankTOM_2011_mr['bottom']]

PlankTOM_2012_Rec_new = PlankTOM_2012_mr.loc[PlankTOM_2012_mr['depth'] < PlankTOM_2012_mr['bottom']]

PlankTOM_2013_Rec_new = PlankTOM_2013_mr.loc[PlankTOM_2013_mr['depth'] < PlankTOM_2013_mr['bottom']]

# %%
All_Data_Pl_new2 = All_Data_Pl_new[['POC', 'GOC','depth', 'Temp', 'Temp_back', 'MLD', 'O2', 'O2_back', 'NO3',\
                                    'NO3_back', 'PO4', 'PO4_back', 'Si', 'Si_back', 'CHL','CHL_back',\
                                    'BAC','MES', 'PTE', 'DIA', 'COC', 'PIC', 'PHA', 'GEL','PRO', 'MAC', 'MIX', 'FIX',\
                                    'BAC_back','MES_back', 'PTE_back', 'DIA_back', 'COC_back', 'PIC_back', 'PHA_back',\
                                    'GEL_back','PRO_back', 'MAC_back', 'MIX_back', 'FIX_back',\
                                    'O2_mean','NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean', 'CHL_back_mean',\
                                    'O2_back_mean','NO3_back_mean', 'PO4_back_mean', 'Si_back_mean', 
                                    'BAC_mean','MES_mean','PTE_mean', 'DIA_mean', 'COC_mean', 'PIC_mean', 'PHA_mean',\
                                    'GEL_mean','PRO_mean', 'MAC_mean', 'MIX_mean', 'FIX_mean', 'Big_zoopl',\
                                    'BAC_back_mean','MES_back_mean','PTE_back_mean', 'DIA_back_mean', 'COC_back_mean',\
                                    'PIC_back_mean', 'PHA_back_mean',\
                                    'GEL_back_mean','PRO_back_mean', 'MAC_back_mean', 'MIX_back_mean', 'FIX_back_mean', 
                                    'Big_zoopl2','year', 'month', 'lat_Pl','lon_Pl','bottom',\
                                    'coordinates']]

# %%
All_Data_RK_new2 = All_Data_RK_new[['POC', 'GOC','depth', 'Temp', 'Temp_back', 'MLD', 'O2', 'O2_back', 'NO3',\
                                    'NO3_back', 'PO4', 'PO4_back', 'Si', 'Si_back', 'CHL','CHL_back',\
                                    'BAC','MES', 'PTE', 'DIA', 'COC', 'PIC', 'PHA', 'GEL','PRO', 'MAC', 'MIX', 'FIX',\
                                    'BAC_back','MES_back', 'PTE_back', 'DIA_back', 'COC_back', 'PIC_back', 'PHA_back',\
                                    'GEL_back','PRO_back', 'MAC_back', 'MIX_back', 'FIX_back',\
                                    'O2_mean','NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean', 'CHL_back_mean',\
                                    'O2_back_mean','NO3_back_mean', 'PO4_back_mean', 'Si_back_mean', 
                                    'BAC_mean','MES_mean','PTE_mean', 'DIA_mean', 'COC_mean', 'PIC_mean', 'PHA_mean',\
                                    'GEL_mean','PRO_mean', 'MAC_mean', 'MIX_mean', 'FIX_mean', 'Big_zoopl',\
                                    'BAC_back_mean','MES_back_mean','PTE_back_mean', 'DIA_back_mean', 'COC_back_mean',\
                                    'PIC_back_mean', 'PHA_back_mean',\
                                    'GEL_back_mean','PRO_back_mean', 'MAC_back_mean', 'MIX_back_mean', 'FIX_back_mean', 
                                    'Big_zoopl2','year', 'month', 'lat_Pl','lon_Pl','bottom',\
                                    'coordinates']]

# %%
#concatenate all data from UVP5 and Tara positions localized in PalnkTOM12
All_Data_concat = pd.concat([All_Data_Pl_new2, All_Data_RK_new2],ignore_index=True, sort=False).sort_values(['coordinates', 'depth','year','month']).reset_index()
All_Data_final2 = All_Data_concat.drop(['index'], axis=1)
All_Data_final = All_Data_final2.drop_duplicates()

# %%
PlankTOM_2009_new2 = PlankTOM_2009_Rec_new[['POC', 'GOC','depth', 'Temp', 'MLD', 'O2', 'NO3', 'PO4','Si', 'CHL','CHL_back',\
                                    'BAC','MES', 'PTE', 'DIA', 'COC', 'PIC', 'PHA', 'GEL','PRO', 'MAC', 'MIX', 'FIX',\
                                    'O2_mean','NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean', 'CHL_back_mean',\
                                    'BAC_mean','MES_mean','PTE_mean', 'DIA_mean', 'COC_mean', 'PIC_mean', 'PHA_mean',\
                                    'GEL_mean','PRO_mean', 'MAC_mean', 'MIX_mean', 'FIX_mean', 'Big_zoopl',\
                                    'Big_zoopl2','year', 'month','lat_Pl','lon_Pl','bottom',\
                                    'coordinates']]

PlankTOM_2010_new2 = PlankTOM_2010_Rec_new[['POC', 'GOC','depth', 'Temp', 'MLD', 'O2', 'NO3', 'PO4','Si', 'CHL','CHL_back',\
                                    'BAC','MES', 'PTE', 'DIA', 'COC', 'PIC', 'PHA', 'GEL','PRO', 'MAC', 'MIX', 'FIX',\
                                    'O2_mean','NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean', 'CHL_back_mean',\
                                    'BAC_mean','MES_mean','PTE_mean', 'DIA_mean', 'COC_mean', 'PIC_mean', 'PHA_mean',\
                                    'GEL_mean','PRO_mean', 'MAC_mean', 'MIX_mean', 'FIX_mean', 'Big_zoopl',\
                                    'Big_zoopl2','year', 'month','lat_Pl','lon_Pl','bottom',\
                                    'coordinates']]

PlankTOM_2011_new2 = PlankTOM_2011_Rec_new[['POC', 'GOC','depth', 'Temp', 'MLD', 'O2', 'NO3', 'PO4','Si', 'CHL','CHL_back',\
                                    'BAC','MES', 'PTE', 'DIA', 'COC', 'PIC', 'PHA', 'GEL','PRO', 'MAC', 'MIX', 'FIX',\
                                    'O2_mean','NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean', 'CHL_back_mean',\
                                    'BAC_mean','MES_mean','PTE_mean', 'DIA_mean', 'COC_mean', 'PIC_mean', 'PHA_mean',\
                                    'GEL_mean','PRO_mean', 'MAC_mean', 'MIX_mean', 'FIX_mean', 'Big_zoopl',\
                                    'Big_zoopl2','year', 'month','lat_Pl','lon_Pl','bottom',\
                                    'coordinates']]

PlankTOM_2012_new2 = PlankTOM_2012_Rec_new[['POC', 'GOC','depth', 'Temp', 'MLD', 'O2', 'NO3', 'PO4','Si', 'CHL','CHL_back',\
                                    'BAC','MES', 'PTE', 'DIA', 'COC', 'PIC', 'PHA', 'GEL','PRO', 'MAC', 'MIX', 'FIX',\
                                    'O2_mean','NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean', 'CHL_back_mean',\
                                    'BAC_mean','MES_mean','PTE_mean', 'DIA_mean', 'COC_mean', 'PIC_mean', 'PHA_mean',\
                                    'GEL_mean','PRO_mean', 'MAC_mean', 'MIX_mean', 'FIX_mean', 'Big_zoopl',\
                                    'Big_zoopl2','year', 'month','lat_Pl','lon_Pl','bottom',\
                                    'coordinates']]

PlankTOM_2013_new2 = PlankTOM_2013_Rec_new[['POC', 'GOC','depth', 'Temp', 'MLD', 'O2', 'NO3', 'PO4','Si', 'CHL','CHL_back',\
                                    'BAC','MES', 'PTE', 'DIA', 'COC', 'PIC', 'PHA', 'GEL','PRO', 'MAC', 'MIX', 'FIX',\
                                    'O2_mean','NO3_mean', 'PO4_mean', 'Si_mean', 'CHL_mean', 'CHL_back_mean',\
                                    'BAC_mean','MES_mean','PTE_mean', 'DIA_mean', 'COC_mean', 'PIC_mean', 'PHA_mean',\
                                    'GEL_mean','PRO_mean', 'MAC_mean', 'MIX_mean', 'FIX_mean', 'Big_zoopl',\
                                    'Big_zoopl2','year', 'month','lat_Pl','lon_Pl','bottom',\
                                    'coordinates']]

# %%
#remove values deeper than 1600m
PlankTOM_2009_new3 = PlankTOM_2009_new2.loc[PlankTOM_2009_new2['depth'] < 1600.]
PlankTOM_2010_new3 = PlankTOM_2010_new2.loc[PlankTOM_2010_new2['depth'] < 1600.]
PlankTOM_2011_new3 = PlankTOM_2011_new2.loc[PlankTOM_2011_new2['depth'] < 1600.]
PlankTOM_2012_new3 = PlankTOM_2012_new2.loc[PlankTOM_2012_new2['depth'] < 1600.]
PlankTOM_2013_new3 = PlankTOM_2013_new2.loc[PlankTOM_2013_new2['depth'] < 1600.]

# %%
All_Data_final['POC_log'] = np.log(All_Data_final['POC'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
POC_mean = np.mean(All_Data_final['POC_log']) 
POC_std  = np.std(All_Data_final['POC_log']) 
All_Data_final['POC_norm'] = (All_Data_final['POC_log'] - POC_mean)/POC_std

All_Data_final['GOC_log'] = np.log(All_Data_final['GOC'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
GOC_mean = np.mean(All_Data_final['GOC_log']) 
GOC_std  = np.std(All_Data_final['GOC_log']) 
All_Data_final['GOC_norm'] = (All_Data_final['GOC_log'] - GOC_mean)/GOC_std

All_Data_final['depth_log'] = np.log(All_Data_final['depth'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
depth_mean = np.mean(All_Data_final['depth_log']) 
depth_std  = np.std(All_Data_final['depth_log']) 
All_Data_final['depth_norm'] = (All_Data_final['depth_log'] - depth_mean)/depth_std

Temp_mean = np.mean(All_Data_final['Temp']) 
Temp_std  = np.std(All_Data_final['Temp']) 
All_Data_final['Temp_norm'] = (All_Data_final['Temp'] - Temp_mean)/Temp_std

Temp_back_mean = np.mean(All_Data_final['Temp_back']) 
Temp_back_std  = np.std(All_Data_final['Temp_back']) 
All_Data_final['Temp_back_norm'] = (All_Data_final['Temp_back'] - Temp_back_mean)/Temp_back_std

All_Data_final['MLD_log'] = np.log(All_Data_final['MLD'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
MLD_mean = np.mean(All_Data_final['MLD_log']) 
MLD_std  = np.std(All_Data_final['MLD_log']) 
All_Data_final['MLD_norm'] = (All_Data_final['MLD_log'] - MLD_mean)/MLD_std

O2_mean = np.mean(All_Data_final['O2']) 
O2_std  = np.std(All_Data_final['O2']) 
All_Data_final['O2_norm'] = (All_Data_final['O2'] - O2_mean)/O2_std

O2_back_mean = np.mean(All_Data_final['O2_back']) 
O2_back_std  = np.std(All_Data_final['O2_back']) 
All_Data_final['O2_back_norm'] = (All_Data_final['O2_back'] - O2_back_mean)/O2_back_std

NO3_mean = np.mean(All_Data_final['NO3']) 
NO3_std  = np.std(All_Data_final['NO3']) 
All_Data_final['NO3_norm'] = (All_Data_final['NO3'] - NO3_mean)/NO3_std

NO3_back_mean = np.mean(All_Data_final['NO3_back']) 
NO3_back_std  = np.std(All_Data_final['NO3_back']) 
All_Data_final['NO3_back_norm'] = (All_Data_final['NO3_back'] - NO3_back_mean)/NO3_back_std

PO4_mean = np.mean(All_Data_final['PO4']) 
PO4_std  = np.std(All_Data_final['PO4']) 
All_Data_final['PO4_norm'] = (All_Data_final['PO4'] - PO4_mean)/PO4_std

PO4_back_mean = np.mean(All_Data_final['PO4_back']) 
PO4_back_std  = np.std(All_Data_final['PO4_back']) 
All_Data_final['PO4_back_norm'] = (All_Data_final['PO4_back'] - PO4_back_mean)/PO4_back_std

Si_mean = np.mean(All_Data_final['Si']) 
Si_std  = np.std(All_Data_final['Si']) 
All_Data_final['Si_norm'] = (All_Data_final['Si'] - Si_mean)/Si_std

Si_back_mean = np.mean(All_Data_final['Si_back']) 
Si_back_std  = np.std(All_Data_final['Si_back']) 
All_Data_final['Si_back_norm'] = (All_Data_final['Si_back'] - Si_back_mean)/Si_back_std

All_Data_final['CHL_log'] = np.log(All_Data_final['CHL'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
CHL_mean = np.mean(All_Data_final['CHL_log']) 
CHL_std  = np.std(All_Data_final['CHL_log']) 
All_Data_final['CHL_norm'] = (All_Data_final['CHL_log'] - CHL_mean)/CHL_std

All_Data_final['CHL_back_log'] = np.log(All_Data_final['CHL_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
CHL_back_mean = np.mean(All_Data_final['CHL_back_log']) 
CHL_back_std  = np.std(All_Data_final['CHL_back_log']) 
All_Data_final['CHL_back_norm'] = (All_Data_final['CHL_back_log'] - CHL_back_mean)/CHL_back_std

All_Data_final['BAC_log'] = np.log(All_Data_final['BAC'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
BAC_mean = np.mean(All_Data_final['BAC_log']) 
BAC_std  = np.std(All_Data_final['BAC_log']) 
All_Data_final['BAC_norm'] = (All_Data_final['BAC_log'] - BAC_mean)/BAC_std

All_Data_final['BAC_back_log'] = np.log(All_Data_final['BAC_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
BAC_back_mean = np.mean(All_Data_final['BAC_back_log']) 
BAC_back_std  = np.std(All_Data_final['BAC_back_log']) 
All_Data_final['BAC_back_norm'] = (All_Data_final['BAC_back_log'] - BAC_back_mean)/BAC_back_std

All_Data_final['MES_log'] = np.log(All_Data_final['MES'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
MES_mean = np.mean(All_Data_final['MES_log']) 
MES_std  = np.std(All_Data_final['MES_log']) 
All_Data_final['MES_norm'] = (All_Data_final['MES_log'] - MES_mean)/MES_std

All_Data_final['MES_back_log'] = np.log(All_Data_final['MES_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
MES_back_mean = np.mean(All_Data_final['MES_back_log']) 
MES_back_std  = np.std(All_Data_final['MES_back_log']) 
All_Data_final['MES_back_norm'] = (All_Data_final['MES_back_log'] - MES_back_mean)/MES_back_std

All_Data_final['PTE_log'] = np.log(All_Data_final['PTE'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
PTE_mean = np.mean(All_Data_final['PTE_log']) 
PTE_std  = np.std(All_Data_final['PTE_log']) 
All_Data_final['PTE_norm'] = (All_Data_final['PTE_log'] - PTE_mean)/PTE_std

All_Data_final['PTE_back_log'] = np.log(All_Data_final['PTE_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
PTE_back_mean = np.mean(All_Data_final['PTE_back_log']) 
PTE_back_std  = np.std(All_Data_final['PTE_back_log']) 
All_Data_final['PTE_back_norm'] = (All_Data_final['PTE_back_log'] - PTE_back_mean)/PTE_back_std

All_Data_final['DIA_log'] = np.log(All_Data_final['DIA'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
DIA_mean = np.mean(All_Data_final['DIA_log']) 
DIA_std  = np.std(All_Data_final['DIA_log']) 
All_Data_final['DIA_norm'] = (All_Data_final['DIA_log'] - DIA_mean)/DIA_std

All_Data_final['DIA_back_log'] = np.log(All_Data_final['DIA_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
DIA_back_mean = np.mean(All_Data_final['DIA_back_log']) 
DIA_back_std  = np.std(All_Data_final['DIA_back_log']) 
All_Data_final['DIA_back_norm'] = (All_Data_final['DIA_back_log'] - DIA_back_mean)/DIA_back_std

All_Data_final['COC_log'] = np.log(All_Data_final['COC'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
COC_mean = np.mean(All_Data_final['COC_log']) 
COC_std  = np.std(All_Data_final['COC_log']) 
All_Data_final['COC_norm'] = (All_Data_final['COC_log'] - COC_mean)/COC_std

All_Data_final['COC_back_log'] = np.log(All_Data_final['COC_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
COC_back_mean = np.mean(All_Data_final['COC_back_log']) 
COC_back_std  = np.std(All_Data_final['COC_back_log']) 
All_Data_final['COC_back_norm'] = (All_Data_final['COC_back_log'] - COC_back_mean)/COC_back_std

All_Data_final['PIC_log'] = np.log(All_Data_final['PIC'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
PIC_mean = np.mean(All_Data_final['PIC_log']) 
PIC_std  = np.std(All_Data_final['PIC_log']) 
All_Data_final['PIC_norm'] = (All_Data_final['PIC_log'] - PIC_mean)/PIC_std

All_Data_final['PIC_back_log'] = np.log(All_Data_final['PIC_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
PIC_back_mean = np.mean(All_Data_final['PIC_back_log']) 
PIC_back_std  = np.std(All_Data_final['PIC_back_log']) 
All_Data_final['PIC_back_norm'] = (All_Data_final['PIC_back_log'] - PIC_back_mean)/PIC_back_std

All_Data_final['PHA_log'] = np.log(All_Data_final['PHA'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
PHA_mean = np.mean(All_Data_final['PHA_log']) 
PHA_std  = np.std(All_Data_final['PHA_log']) 
All_Data_final['PHA_norm'] = (All_Data_final['PHA_log'] - PHA_mean)/PHA_std

All_Data_final['PHA_back_log'] = np.log(All_Data_final['PHA_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
PHA_back_mean = np.mean(All_Data_final['PHA_back_log']) 
PHA_back_std  = np.std(All_Data_final['PHA_back_log']) 
All_Data_final['PHA_back_norm'] = (All_Data_final['PHA_back_log'] - PHA_back_mean)/PHA_back_std

All_Data_final['GEL_log'] = np.log(All_Data_final['GEL'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
GEL_mean = np.mean(All_Data_final['GEL_log']) 
GEL_std  = np.std(All_Data_final['GEL_log']) 
All_Data_final['GEL_norm'] = (All_Data_final['GEL_log'] - GEL_mean)/GEL_std

All_Data_final['GEL_back_log'] = np.log(All_Data_final['GEL_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
GEL_back_mean = np.mean(All_Data_final['GEL_back_log']) 
GEL_back_std  = np.std(All_Data_final['GEL_back_log']) 
All_Data_final['GEL_back_norm'] = (All_Data_final['GEL_back_log'] - GEL_back_mean)/GEL_back_std

All_Data_final['PRO_log'] = np.log(All_Data_final['PRO'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
PRO_mean = np.mean(All_Data_final['PRO_log']) 
PRO_std  = np.std(All_Data_final['PRO_log']) 
All_Data_final['PRO_norm'] = (All_Data_final['PRO_log'] - PRO_mean)/PRO_std

All_Data_final['PRO_back_log'] = np.log(All_Data_final['PRO_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
PRO_back_mean = np.mean(All_Data_final['PRO_back_log']) 
PRO_back_std  = np.std(All_Data_final['PRO_back_log']) 
All_Data_final['PRO_back_norm'] = (All_Data_final['PRO_back_log'] - PRO_back_mean)/PRO_back_std

All_Data_final['MAC_log'] = np.log(All_Data_final['MAC'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
MAC_mean = np.mean(All_Data_final['MAC_log']) 
MAC_std  = np.std(All_Data_final['MAC_log']) 
All_Data_final['MAC_norm'] = (All_Data_final['MAC_log'] - MAC_mean)/MAC_std

All_Data_final['MAC_back_log'] = np.log(All_Data_final['MAC_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
MAC_back_mean = np.mean(All_Data_final['MAC_back_log']) 
MAC_back_std  = np.std(All_Data_final['MAC_back_log']) 
All_Data_final['MAC_back_norm'] = (All_Data_final['MAC_back_log'] - MAC_back_mean)/MAC_back_std

All_Data_final['MIX_log'] = np.log(All_Data_final['MIX'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
MIX_mean = np.mean(All_Data_final['MIX_log']) 
MIX_std  = np.std(All_Data_final['MIX_log']) 
All_Data_final['MIX_norm'] = (All_Data_final['MIX_log'] - MIX_mean)/MIX_std

All_Data_final['MIX_back_log'] = np.log(All_Data_final['MIX_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
MIX_back_mean = np.mean(All_Data_final['MIX_back_log']) 
MIX_back_std  = np.std(All_Data_final['MIX_back_log']) 
All_Data_final['MIX_back_norm'] = (All_Data_final['MIX_back_log'] - MIX_back_mean)/MIX_back_std

All_Data_final['FIX_log'] = np.log(All_Data_final['FIX'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
FIX_mean = np.mean(All_Data_final['FIX_log']) 
FIX_std  = np.std(All_Data_final['FIX_log']) 
All_Data_final['FIX_norm'] = (All_Data_final['FIX_log'] - FIX_mean)/FIX_std

All_Data_final['FIX_back_log'] = np.log(All_Data_final['FIX_back'])
All_Data_final = All_Data_final.replace([np.inf,-np.inf],0.)
FIX_back_mean = np.mean(All_Data_final['FIX_back_log']) 
FIX_back_std  = np.std(All_Data_final['FIX_back_log']) 
All_Data_final['FIX_back_norm'] = (All_Data_final['FIX_back_log'] - FIX_back_mean)/FIX_back_std

O2_m_mean = np.mean(All_Data_final['O2_mean']) 
O2_m_std  = np.std(All_Data_final['O2_mean']) 
All_Data_final['O2_mean_norm'] = (All_Data_final['O2_mean'] - O2_m_mean)/O2_m_std

O2_back_m_mean = np.mean(All_Data_final['O2_back_mean']) 
O2_back_m_std  = np.std(All_Data_final['O2_back_mean']) 
All_Data_final['O2_back_mean_norm'] = (All_Data_final['O2_back_mean'] - O2_back_m_mean)/O2_back_m_std

NO3_m_mean = np.mean(All_Data_final['NO3_mean']) 
NO3_m_std  = np.std(All_Data_final['NO3_mean']) 
All_Data_final['NO3_mean_norm'] = (All_Data_final['NO3_mean'] - NO3_m_mean)/NO3_m_std

NO3_back_m_mean = np.mean(All_Data_final['NO3_back_mean']) 
NO3_back_m_std  = np.std(All_Data_final['NO3_back_mean']) 
All_Data_final['NO3_back_mean_norm'] = (All_Data_final['NO3_back_mean'] - NO3_back_m_mean)/NO3_back_m_std

PO4_m_mean = np.mean(All_Data_final['PO4_mean']) 
PO4_m_std  = np.std(All_Data_final['PO4_mean']) 
All_Data_final['PO4_mean_norm'] = (All_Data_final['PO4_mean'] - PO4_m_mean)/PO4_m_std

PO4_back_m_mean = np.mean(All_Data_final['PO4_back_mean']) 
PO4_back_m_std  = np.std(All_Data_final['PO4_back_mean']) 
All_Data_final['PO4_back_mean_norm'] = (All_Data_final['PO4_back_mean'] - PO4_back_m_mean)/PO4_back_m_std

Si_m_mean = np.mean(All_Data_final['Si_mean']) 
Si_m_std  = np.std(All_Data_final['Si_mean']) 
All_Data_final['Si_mean_norm'] = (All_Data_final['Si_mean'] - Si_m_mean)/Si_m_std

Si_back_m_mean = np.mean(All_Data_final['Si_back_mean']) 
Si_back_m_std  = np.std(All_Data_final['Si_back_mean']) 
All_Data_final['Si_back_mean_norm'] = (All_Data_final['Si_back_mean'] - Si_back_m_mean)/Si_back_m_std

CHL_m_mean = np.mean(All_Data_final['CHL_mean']) 
CHL_m_std  = np.std(All_Data_final['CHL']) 
All_Data_final['CHL_mean_norm'] = (All_Data_final['CHL_mean'] - CHL_m_mean)/CHL_m_std

CHL_back_m_mean = np.mean(All_Data_final['CHL_back_mean']) 
CHL_back_m_std  = np.std(All_Data_final['CHL_back_mean']) 
All_Data_final['CHL_back_mean_norm'] = (All_Data_final['CHL_back_mean'] - CHL_back_m_mean)/CHL_back_m_std

BAC_m_mean = np.mean(All_Data_final['BAC_mean']) 
BAC_m_std  = np.std(All_Data_final['BAC_mean']) 
All_Data_final['BAC_mean_norm'] = (All_Data_final['BAC_mean'] - BAC_m_mean)/BAC_m_std

MES_m_mean = np.mean(All_Data_final['MES_mean']) 
MES_m_std  = np.std(All_Data_final['MES_mean']) 
All_Data_final['MES_mean_norm'] = (All_Data_final['MES_mean'] - MES_m_mean)/MES_m_std

PTE_m_mean = np.mean(All_Data_final['PTE_mean']) 
PTE_m_std  = np.std(All_Data_final['PTE_mean']) 
All_Data_final['PTE_mean_norm'] = (All_Data_final['PTE_mean'] - PTE_m_mean)/PTE_m_std

DIA_m_mean = np.mean(All_Data_final['DIA_mean']) 
DIA_m_std  = np.std(All_Data_final['DIA_mean']) 
All_Data_final['DIA_mean_norm'] = (All_Data_final['DIA_mean'] - DIA_m_mean)/DIA_m_std

COC_m_mean = np.mean(All_Data_final['COC_mean']) 
COC_m_std  = np.std(All_Data_final['COC_mean']) 
All_Data_final['COC_mean_norm'] = (All_Data_final['COC_mean'] - COC_m_mean)/COC_m_std

PIC_m_mean = np.mean(All_Data_final['PIC_mean']) 
PIC_m_std  = np.std(All_Data_final['PIC_mean']) 
All_Data_final['PIC_mean_norm'] = (All_Data_final['PIC_mean'] - PIC_m_mean)/PIC_m_std

PHA_m_mean = np.mean(All_Data_final['PHA_mean']) 
PHA_m_std  = np.std(All_Data_final['PHA_mean']) 
All_Data_final['PHA_mean_norm'] = (All_Data_final['PHA_mean'] - PHA_m_mean)/PHA_m_std

GEL_m_mean = np.mean(All_Data_final['GEL_mean']) 
GEL_m_std  = np.std(All_Data_final['GEL_mean']) 
All_Data_final['GEL_mean_norm'] = (All_Data_final['GEL_mean'] - GEL_m_mean)/GEL_m_std

PRO_m_mean = np.mean(All_Data_final['PRO_mean']) 
PRO_m_std  = np.std(All_Data_final['PRO_mean'])
All_Data_final['PRO_mean_norm'] = (All_Data_final['PRO_mean'] - PRO_m_mean)/PRO_m_std

MAC_m_mean = np.mean(All_Data_final['MAC_mean']) 
MAC_m_std  = np.std(All_Data_final['MAC_mean']) 
All_Data_final['MAC_mean_norm'] = (All_Data_final['MAC_mean'] - MAC_m_mean)/MAC_m_std

MIX_m_mean = np.mean(All_Data_final['MIX_mean']) 
MIX_m_std  = np.std(All_Data_final['MIX_mean'])
All_Data_final['MIX_mean_norm'] = (All_Data_final['MIX_mean'] - MIX_m_mean)/MIX_m_std

FIX_m_mean = np.mean(All_Data_final['FIX_mean'])
FIX_m_std  = np.std(All_Data_final['FIX_mean']) 
All_Data_final['FIX_mean_norm'] = (All_Data_final['FIX_mean'] - FIX_m_mean)/FIX_m_std

BAC_back_m_mean = np.mean(All_Data_final['BAC_back_mean']) 
BAC_back_m_std  = np.std(All_Data_final['BAC_back_mean']) 
All_Data_final['BAC_back_mean_norm'] = (All_Data_final['BAC_back_mean'] - BAC_back_m_mean)/BAC_back_m_std

MES_back_m_mean = np.mean(All_Data_final['MES_back_mean']) 
MES_back_m_std  = np.std(All_Data_final['MES_back_mean']) 
All_Data_final['MES_back_mean_norm'] = (All_Data_final['MES_back_mean'] - MES_back_m_mean)/MES_back_m_std

PTE_back_m_mean = np.mean(All_Data_final['PTE_back_mean']) 
PTE_back_m_std  = np.std(All_Data_final['PTE_back_mean']) 
All_Data_final['PTE_back_mean_norm'] = (All_Data_final['PTE_back_mean'] - PTE_back_m_mean)/PTE_back_m_std

DIA_back_m_mean = np.mean(All_Data_final['DIA_back_mean']) 
DIA_back_m_std  = np.std(All_Data_final['DIA_back_mean']) 
All_Data_final['DIA_back_mean_norm'] = (All_Data_final['DIA_back_mean'] - DIA_back_m_mean)/DIA_back_m_std

COC_back_m_mean = np.mean(All_Data_final['COC_back_mean']) 
COC_back_m_std  = np.std(All_Data_final['COC_back_mean']) 
All_Data_final['COC_back_mean_norm'] = (All_Data_final['COC_back_mean'] - COC_back_m_mean)/COC_back_m_std

PIC_back_m_mean = np.mean(All_Data_final['PIC_back_mean']) 
PIC_back_m_std  = np.std(All_Data_final['PIC_back_mean']) 
All_Data_final['PIC_back_mean_norm'] = (All_Data_final['PIC_back_mean'] - PIC_back_m_mean)/PIC_back_m_std

PHA_back_m_mean = np.mean(All_Data_final['PHA_back_mean']) 
PHA_back_m_std  = np.std(All_Data_final['PHA_back_mean']) 
All_Data_final['PHA_back_mean_norm'] = (All_Data_final['PHA_back_mean'] - PHA_back_m_mean)/PHA_back_m_std

GEL_back_m_mean = np.mean(All_Data_final['GEL_back_mean']) 
GEL_back_m_std  = np.std(All_Data_final['GEL_back_mean']) 
All_Data_final['GEL_back_mean_norm'] = (All_Data_final['GEL_back_mean'] - GEL_back_m_mean)/GEL_back_m_std

PRO_back_m_mean = np.mean(All_Data_final['PRO_back_mean']) 
PRO_back_m_std  = np.std(All_Data_final['PRO_back_mean'])
All_Data_final['PRO_back_mean_norm'] = (All_Data_final['PRO_back_mean'] - PRO_back_m_mean)/PRO_back_m_std

MAC_back_m_mean = np.mean(All_Data_final['MAC_back_mean']) 
MAC_back_m_std  = np.std(All_Data_final['MAC_back_mean']) 
All_Data_final['MAC_back_mean_norm'] = (All_Data_final['MAC_back_mean'] - MAC_back_m_mean)/MAC_back_m_std

MIX_back_m_mean = np.mean(All_Data_final['MIX_back_mean']) 
MIX_back_m_std  = np.std(All_Data_final['MIX_back_mean'])
All_Data_final['MIX_back_mean_norm'] = (All_Data_final['MIX_back_mean'] - MIX_back_m_mean)/MIX_back_m_std

FIX_back_m_mean = np.mean(All_Data_final['FIX_back_mean'])
FIX_back_m_std  = np.std(All_Data_final['FIX_back_mean']) 
All_Data_final['FIX_back_mean_norm'] = (All_Data_final['FIX_back_mean'] - FIX_back_m_mean)/FIX_back_m_std
# Out:
# /Users/annasommer/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/annasommer/opt/miniconda3/lib/python3.7/site-packages/pandas/core/series.py:856: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
All_Data_IV_Pl_new['POC_log'] = np.log(All_Data_IV_Pl_new['POC'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['POC_norm'] = (All_Data_IV_Pl_new['POC_log'] - POC_mean)/POC_std

All_Data_IV_Pl_new['GOC_log'] = np.log(All_Data_IV_Pl_new['GOC'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['GOC_norm'] = (All_Data_IV_Pl_new['GOC_log'] - GOC_mean)/GOC_std

All_Data_IV_Pl_new['depth_log'] = np.log(All_Data_IV_Pl_new['depth'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['depth_norm'] = (All_Data_IV_Pl_new['depth_log'] - depth_mean)/depth_std

All_Data_IV_Pl_new['Temp_norm'] = (All_Data_IV_Pl_new['Temp'] - Temp_mean)/Temp_std

All_Data_IV_Pl_new['Temp_back_norm'] = (All_Data_IV_Pl_new['Temp_back'] - Temp_back_mean)/Temp_back_std

All_Data_IV_Pl_new['MLD_log'] = np.log(All_Data_IV_Pl_new['MLD'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['MLD_norm'] = (All_Data_IV_Pl_new['MLD_log'] - MLD_mean)/MLD_std

All_Data_IV_Pl_new['O2_norm'] = (All_Data_IV_Pl_new['O2'] - O2_mean)/O2_std

All_Data_IV_Pl_new['NO3_norm'] = (All_Data_IV_Pl_new['NO3'] - NO3_mean)/NO3_std

All_Data_IV_Pl_new['PO4_norm'] = (All_Data_IV_Pl_new['PO4'] - PO4_mean)/PO4_std

All_Data_IV_Pl_new['Si_norm'] = (All_Data_IV_Pl_new['Si'] - Si_mean)/Si_std

All_Data_IV_Pl_new['O2_back_norm'] = (All_Data_IV_Pl_new['O2_back'] - O2_back_mean)/O2_back_std

All_Data_IV_Pl_new['NO3_back_norm'] = (All_Data_IV_Pl_new['NO3_back'] - NO3_back_mean)/NO3_back_std

All_Data_IV_Pl_new['PO4_back_norm'] = (All_Data_IV_Pl_new['PO4_back'] - PO4_back_mean)/PO4_back_std

All_Data_IV_Pl_new['Si_back_norm'] = (All_Data_IV_Pl_new['Si_back'] - Si_back_mean)/Si_back_std

All_Data_IV_Pl_new['CHL_log'] = np.log(All_Data_IV_Pl_new['CHL'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['CHL_norm'] = (All_Data_IV_Pl_new['CHL_log'] - CHL_mean)/CHL_std

All_Data_IV_Pl_new['CHL_back_log'] = np.log(All_Data_IV_Pl_new['CHL_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['CHL_back_norm'] = (All_Data_IV_Pl_new['CHL_back_log'] - CHL_back_mean)/CHL_back_std

All_Data_IV_Pl_new['BAC_log'] = np.log(All_Data_IV_Pl_new['BAC'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['BAC_norm'] = (All_Data_IV_Pl_new['BAC_log'] - BAC_mean)/BAC_std

All_Data_IV_Pl_new['BAC_back_log'] = np.log(All_Data_IV_Pl_new['BAC_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['BAC_back_norm'] = (All_Data_IV_Pl_new['BAC_back_log'] - BAC_back_mean)/BAC_back_std

All_Data_IV_Pl_new['MES_log'] = np.log(All_Data_IV_Pl_new['MES'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['MES_norm'] = (All_Data_IV_Pl_new['MES_log'] - MES_mean)/MES_std

All_Data_IV_Pl_new['MES_back_log'] = np.log(All_Data_IV_Pl_new['MES_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['MES_back_norm'] = (All_Data_IV_Pl_new['MES_back_log'] - MES_back_mean)/MES_back_std

All_Data_IV_Pl_new['PTE_log'] = np.log(All_Data_IV_Pl_new['PTE'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['PTE_norm'] = (All_Data_IV_Pl_new['PTE_log'] - PTE_mean)/PTE_std

All_Data_IV_Pl_new['PTE_back_log'] = np.log(All_Data_IV_Pl_new['PTE_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['PTE_back_norm'] = (All_Data_IV_Pl_new['PTE_back_log'] - PTE_back_mean)/PTE_back_std

All_Data_IV_Pl_new['DIA_log'] = np.log(All_Data_IV_Pl_new['DIA'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['DIA_norm'] = (All_Data_IV_Pl_new['DIA_log'] - DIA_mean)/DIA_std

All_Data_IV_Pl_new['DIA_back_log'] = np.log(All_Data_IV_Pl_new['DIA_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['DIA_back_norm'] = (All_Data_IV_Pl_new['DIA_back_log'] - DIA_back_mean)/DIA_back_std

All_Data_IV_Pl_new['COC_log'] = np.log(All_Data_IV_Pl_new['COC'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['COC_norm'] = (All_Data_IV_Pl_new['COC_log'] - COC_mean)/COC_std

All_Data_IV_Pl_new['COC_back_log'] = np.log(All_Data_IV_Pl_new['COC_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['COC_back_norm'] = (All_Data_IV_Pl_new['COC_back_log'] - COC_back_mean)/COC_back_std

All_Data_IV_Pl_new['PIC_log'] = np.log(All_Data_IV_Pl_new['PIC'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['PIC_norm'] = (All_Data_IV_Pl_new['PIC_log'] - PIC_mean)/PIC_std

All_Data_IV_Pl_new['PIC_back_log'] = np.log(All_Data_IV_Pl_new['PIC_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['PIC_back_norm'] = (All_Data_IV_Pl_new['PIC_back_log'] - PIC_back_mean)/PIC_back_std

All_Data_IV_Pl_new['PHA_log'] = np.log(All_Data_IV_Pl_new['PHA'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['PHA_norm'] = (All_Data_IV_Pl_new['PHA_log'] - PHA_mean)/PHA_std

All_Data_IV_Pl_new['PHA_back_log'] = np.log(All_Data_IV_Pl_new['PHA_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['PHA_back_norm'] = (All_Data_IV_Pl_new['PHA_back_log'] - PHA_back_mean)/PHA_back_std

All_Data_IV_Pl_new['GEL_log'] = np.log(All_Data_IV_Pl_new['GEL'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['GEL_norm'] = (All_Data_IV_Pl_new['GEL_log'] - GEL_mean)/GEL_std

All_Data_IV_Pl_new['GEL_back_log'] = np.log(All_Data_IV_Pl_new['GEL_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['GEL_back_norm'] = (All_Data_IV_Pl_new['GEL_back_log'] - GEL_back_mean)/GEL_back_std

All_Data_IV_Pl_new['PRO_log'] = np.log(All_Data_IV_Pl_new['PRO'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['PRO_norm'] = (All_Data_IV_Pl_new['PRO_log'] - PRO_mean)/PRO_std

All_Data_IV_Pl_new['PRO_back_log'] = np.log(All_Data_IV_Pl_new['PRO_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['PRO_back_norm'] = (All_Data_IV_Pl_new['PRO_back_log'] - PRO_back_mean)/PRO_back_std

All_Data_IV_Pl_new['MAC_log'] = np.log(All_Data_IV_Pl_new['MAC'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['MAC_norm'] = (All_Data_IV_Pl_new['MAC_log'] - MAC_mean)/MAC_std

All_Data_IV_Pl_new['MAC_back_log'] = np.log(All_Data_IV_Pl_new['MAC_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['MAC_back_norm'] = (All_Data_IV_Pl_new['MAC_back_log'] - MAC_back_mean)/MAC_back_std

All_Data_IV_Pl_new['MIX_log'] = np.log(All_Data_IV_Pl_new['MIX'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['MIX_norm'] = (All_Data_IV_Pl_new['MIX_log'] - MIX_mean)/MIX_std

All_Data_IV_Pl_new['MIX_back_log'] = np.log(All_Data_IV_Pl_new['MIX_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['MIX_back_norm'] = (All_Data_IV_Pl_new['MIX_back_log'] - MIX_back_mean)/MIX_back_std

All_Data_IV_Pl_new['FIX_log'] = np.log(All_Data_IV_Pl_new['FIX'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['FIX_norm'] = (All_Data_IV_Pl_new['FIX_log'] - FIX_mean)/FIX_std

All_Data_IV_Pl_new['FIX_back_log'] = np.log(All_Data_IV_Pl_new['FIX_back'])
All_Data_IV_Pl_new = All_Data_IV_Pl_new.replace([np.inf,-np.inf],0.)
All_Data_IV_Pl_new['FIX_back_norm'] = (All_Data_IV_Pl_new['FIX_back_log'] - FIX_back_mean)/FIX_back_std

All_Data_IV_Pl_new['O2_mean_norm'] = (All_Data_IV_Pl_new['O2_mean'] - O2_m_mean)/O2_m_std

All_Data_IV_Pl_new['NO3_mean_norm'] = (All_Data_IV_Pl_new['NO3_mean'] - NO3_m_mean)/NO3_m_std

All_Data_IV_Pl_new['PO4_mean_norm'] = (All_Data_IV_Pl_new['PO4_mean'] - PO4_m_mean)/PO4_m_std

All_Data_IV_Pl_new['Si_mean_norm'] = (All_Data_IV_Pl_new['Si_mean'] - Si_m_mean)/Si_m_std

All_Data_IV_Pl_new['CHL_mean_norm'] = (All_Data_IV_Pl_new['CHL_mean'] - CHL_m_mean)/CHL_m_std

All_Data_IV_Pl_new['CHL_back_mean_norm'] = (All_Data_IV_Pl_new['CHL_back_mean'] - CHL_back_m_mean)/CHL_back_m_std

All_Data_IV_Pl_new['BAC_mean_norm'] = (All_Data_IV_Pl_new['BAC_mean'] - BAC_m_mean)/BAC_m_std

All_Data_IV_Pl_new['MES_mean_norm'] = (All_Data_IV_Pl_new['MES_mean'] - MES_m_mean)/MES_m_std

All_Data_IV_Pl_new['PTE_mean_norm'] = (All_Data_IV_Pl_new['PTE_mean'] - PTE_m_mean)/PTE_m_std

All_Data_IV_Pl_new['DIA_mean_norm'] = (All_Data_IV_Pl_new['DIA_mean'] - DIA_m_mean)/DIA_m_std

All_Data_IV_Pl_new['COC_mean_norm'] = (All_Data_IV_Pl_new['COC_mean'] - COC_m_mean)/COC_m_std

All_Data_IV_Pl_new['PIC_mean_norm'] = (All_Data_IV_Pl_new['PIC_mean'] - PIC_m_mean)/PIC_m_std

All_Data_IV_Pl_new['PHA_mean_norm'] = (All_Data_IV_Pl_new['PHA_mean'] - PHA_m_mean)/PHA_m_std

All_Data_IV_Pl_new['GEL_mean_norm'] = (All_Data_IV_Pl_new['GEL_mean'] - GEL_m_mean)/GEL_m_std

All_Data_IV_Pl_new['PRO_mean_norm'] = (All_Data_IV_Pl_new['PRO_mean'] - PRO_m_mean)/PRO_m_std

All_Data_IV_Pl_new['MAC_mean_norm'] = (All_Data_IV_Pl_new['MAC_mean'] - MAC_m_mean)/MAC_m_std

All_Data_IV_Pl_new['MIX_mean_norm'] = (All_Data_IV_Pl_new['MIX_mean'] - MIX_m_mean)/MIX_m_std

All_Data_IV_Pl_new['FIX_mean_norm'] = (All_Data_IV_Pl_new['FIX_mean'] - FIX_m_mean)/FIX_m_std


All_Data_IV_Pl_new['O2_back_mean_norm'] = (All_Data_IV_Pl_new['O2_back_mean'] - O2_back_m_mean)/O2_back_m_std

All_Data_IV_Pl_new['NO3_back_mean_norm'] = (All_Data_IV_Pl_new['NO3_back_mean'] - NO3_back_m_mean)/NO3_back_m_std

All_Data_IV_Pl_new['PO4_back_mean_norm'] = (All_Data_IV_Pl_new['PO4_back_mean'] - PO4_back_m_mean)/PO4_back_m_std

All_Data_IV_Pl_new['Si_back_mean_norm'] = (All_Data_IV_Pl_new['Si_back_mean'] - Si_back_m_mean)/Si_back_m_std

All_Data_IV_Pl_new['BAC_back_mean_norm'] = (All_Data_IV_Pl_new['BAC_back_mean'] - BAC_back_m_mean)/BAC_back_m_std

All_Data_IV_Pl_new['MES_back_mean_norm'] = (All_Data_IV_Pl_new['MES_back_mean'] - MES_back_m_mean)/MES_back_m_std

All_Data_IV_Pl_new['PTE_back_mean_norm'] = (All_Data_IV_Pl_new['PTE_back_mean'] - PTE_back_m_mean)/PTE_back_m_std

All_Data_IV_Pl_new['DIA_back_mean_norm'] = (All_Data_IV_Pl_new['DIA_back_mean'] - DIA_back_m_mean)/DIA_back_m_std

All_Data_IV_Pl_new['COC_back_mean_norm'] = (All_Data_IV_Pl_new['COC_back_mean'] - COC_back_m_mean)/COC_back_m_std

All_Data_IV_Pl_new['PIC_back_mean_norm'] = (All_Data_IV_Pl_new['PIC_back_mean'] - PIC_back_m_mean)/PIC_back_m_std

All_Data_IV_Pl_new['PHA_back_mean_norm'] = (All_Data_IV_Pl_new['PHA_back_mean'] - PHA_back_m_mean)/PHA_back_m_std

All_Data_IV_Pl_new['GEL_back_mean_norm'] = (All_Data_IV_Pl_new['GEL_back_mean'] - GEL_back_m_mean)/GEL_back_m_std

All_Data_IV_Pl_new['PRO_back_mean_norm'] = (All_Data_IV_Pl_new['PRO_back_mean'] - PRO_back_m_mean)/PRO_back_m_std

All_Data_IV_Pl_new['MAC_back_mean_norm'] = (All_Data_IV_Pl_new['MAC_back_mean'] - MAC_back_m_mean)/MAC_back_m_std

All_Data_IV_Pl_new['MIX_back_mean_norm'] = (All_Data_IV_Pl_new['MIX_back_mean'] - MIX_back_m_mean)/MIX_back_m_std

All_Data_IV_Pl_new['FIX_back_mean_norm'] = (All_Data_IV_Pl_new['FIX_back_mean'] - FIX_back_m_mean)/FIX_back_m_std
# Out:
# /Users/annasommer/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# PlankTOM_2009_new3['POC_log'] = np.log(PlankTOM_2009_new3['POC'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['POC_norm'] = (PlankTOM_2009_new3['POC_log'] - POC_mean)/POC_std

# PlankTOM_2009_new3['GOC_log'] = np.log(PlankTOM_2009_new3['GOC'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['GOC_norm'] = (PlankTOM_2009_new3['GOC_log'] - GOC_mean)/GOC_std

# PlankTOM_2009_new3['depth_log'] = np.log(PlankTOM_2009_new3['depth'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['depth_norm'] = (PlankTOM_2009_new3['depth_log'] - depth_mean)/depth_std

# PlankTOM_2009_new3['Temp_norm'] = (PlankTOM_2009_new3['Temp'] - Temp_mean)/Temp_std

# PlankTOM_2009_new3['MLD_log'] = np.log(PlankTOM_2009_new3['MLD'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['MLD_norm'] = (PlankTOM_2009_new3['MLD_log'] - MLD_mean)/MLD_std

# PlankTOM_2009_new3['O2_norm'] = (PlankTOM_2009_new3['O2'] - O2_mean)/O2_std

# PlankTOM_2009_new3['NO3_norm'] = (PlankTOM_2009_new3['NO3'] - NO3_mean)/NO3_std

# PlankTOM_2009_new3['PO4_norm'] = (PlankTOM_2009_new3['PO4'] - PO4_mean)/PO4_std

# PlankTOM_2009_new3['Si_norm'] = (PlankTOM_2009_new3['Si'] - Si_mean)/Si_std

# PlankTOM_2009_new3['CHL_log'] = np.log(PlankTOM_2009_new3['CHL'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['CHL_norm'] = (PlankTOM_2009_new3['CHL_log'] - CHL_mean)/CHL_std

# PlankTOM_2009_new3['CHL_back_log'] = np.log(PlankTOM_2009_new3['CHL_back'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['CHL_back_norm'] = (PlankTOM_2009_new3['CHL_back_log'] - CHL_back_mean)/CHL_back_std

# PlankTOM_2009_new3['BAC_log'] = np.log(PlankTOM_2009_new3['BAC'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['BAC_norm'] = (PlankTOM_2009_new3['BAC_log'] - BAC_mean)/BAC_std

# PlankTOM_2009_new3['MES_log'] = np.log(PlankTOM_2009_new3['MES'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['MES_norm'] = (PlankTOM_2009_new3['MES_log'] - MES_mean)/MES_std

# PlankTOM_2009_new3['PTE_log'] = np.log(PlankTOM_2009_new3['PTE'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['PTE_norm'] = (PlankTOM_2009_new3['PTE_log'] - PTE_mean)/PTE_std

# PlankTOM_2009_new3['DIA_log'] = np.log(PlankTOM_2009_new3['DIA'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['DIA_norm'] = (PlankTOM_2009_new3['DIA_log'] - DIA_mean)/DIA_std

# PlankTOM_2009_new3['COC_log'] = np.log(PlankTOM_2009_new3['COC'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['COC_norm'] = (PlankTOM_2009_new3['COC_log'] - COC_mean)/COC_std

# PlankTOM_2009_new3['PIC_log'] = np.log(PlankTOM_2009_new3['PIC'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['PIC_norm'] = (PlankTOM_2009_new3['PIC_log'] - PIC_mean)/PIC_std

# PlankTOM_2009_new3['PHA_log'] = np.log(PlankTOM_2009_new3['PHA'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['PHA_norm'] = (PlankTOM_2009_new3['PHA_log'] - PHA_mean)/PHA_std

# PlankTOM_2009_new3['GEL_log'] = np.log(PlankTOM_2009_new3['GEL'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['GEL_norm'] = (PlankTOM_2009_new3['GEL_log'] - GEL_mean)/GEL_std

# PlankTOM_2009_new3['PRO_log'] = np.log(PlankTOM_2009_new3['PRO'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['PRO_norm'] = (PlankTOM_2009_new3['PRO_log'] - PRO_mean)/PRO_std

# PlankTOM_2009_new3['MAC_log'] = np.log(PlankTOM_2009_new3['MAC'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['MAC_norm'] = (PlankTOM_2009_new3['MAC_log'] - MAC_mean)/MAC_std

# PlankTOM_2009_new3['MIX_log'] = np.log(PlankTOM_2009_new3['MIX'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['MIX_norm'] = (PlankTOM_2009_new3['MIX_log'] - MIX_mean)/MIX_std

# PlankTOM_2009_new3['FIX_log'] = np.log(PlankTOM_2009_new3['FIX'])
# PlankTOM_2009_new3 = PlankTOM_2009_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2009_new3['FIX_norm'] = (PlankTOM_2009_new3['FIX_log'] - FIX_mean)/FIX_std

# PlankTOM_2009_new3['O2_mean_norm'] = (PlankTOM_2009_new3['O2_mean'] - O2_m_mean)/O2_m_std

# PlankTOM_2009_new3['NO3_mean_norm'] = (PlankTOM_2009_new3['NO3_mean'] - NO3_m_mean)/NO3_m_std

# PlankTOM_2009_new3['PO4_mean_norm'] = (PlankTOM_2009_new3['PO4_mean'] - PO4_m_mean)/PO4_m_std

# PlankTOM_2009_new3['Si_mean_norm'] = (PlankTOM_2009_new3['Si_mean'] - Si_m_mean)/Si_m_std

# PlankTOM_2009_new3['CHL_mean_norm'] = (PlankTOM_2009_new3['CHL_mean'] - CHL_m_mean)/CHL_m_std

# PlankTOM_2009_new3['CHL_back_mean_norm'] = (PlankTOM_2009_new3['CHL_back_mean'] - CHL_back_m_mean)/CHL_back_m_std

# PlankTOM_2009_new3['BAC_mean_norm'] = (PlankTOM_2009_new3['BAC_mean'] - BAC_m_mean)/BAC_m_std

# PlankTOM_2009_new3['MES_mean_norm'] = (PlankTOM_2009_new3['MES_mean'] - MES_m_mean)/MES_m_std

# PlankTOM_2009_new3['PTE_mean_norm'] = (PlankTOM_2009_new3['PTE_mean'] - PTE_m_mean)/PTE_m_std

# PlankTOM_2009_new3['DIA_mean_norm'] = (PlankTOM_2009_new3['DIA_mean'] - DIA_m_mean)/DIA_m_std

# PlankTOM_2009_new3['COC_mean_norm'] = (PlankTOM_2009_new3['COC_mean'] - COC_m_mean)/COC_m_std

# PlankTOM_2009_new3['PIC_mean_norm'] = (PlankTOM_2009_new3['PIC_mean'] - PIC_m_mean)/PIC_m_std

# PlankTOM_2009_new3['PHA_mean_norm'] = (PlankTOM_2009_new3['PHA_mean'] - PHA_m_mean)/PHA_m_std

# PlankTOM_2009_new3['GEL_mean_norm'] = (PlankTOM_2009_new3['GEL_mean'] - GEL_m_mean)/GEL_m_std

# PlankTOM_2009_new3['PRO_mean_norm'] = (PlankTOM_2009_new3['PRO_mean'] - PRO_m_mean)/PRO_m_std

# PlankTOM_2009_new3['MAC_mean_norm'] = (PlankTOM_2009_new3['MAC_mean'] - MAC_m_mean)/MAC_m_std

# PlankTOM_2009_new3['MIX_mean_norm'] = (PlankTOM_2009_new3['MIX_mean'] - MIX_m_mean)/MIX_m_std

# PlankTOM_2009_new3['FIX_mean_norm'] = (PlankTOM_2009_new3['FIX_mean'] - FIX_m_mean)/FIX_m_std
# Out:
# /Users/annasommer/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# PlankTOM_2010_new3['POC_log'] = np.log(PlankTOM_2010_new3['POC'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['POC_norm'] = (PlankTOM_2010_new3['POC_log'] - POC_mean)/POC_std

# PlankTOM_2010_new3['GOC_log'] = np.log(PlankTOM_2010_new3['GOC'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['GOC_norm'] = (PlankTOM_2010_new3['GOC_log'] - GOC_mean)/GOC_std

# PlankTOM_2010_new3['depth_log'] = np.log(PlankTOM_2010_new3['depth'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['depth_norm'] = (PlankTOM_2010_new3['depth_log'] - depth_mean)/depth_std

# PlankTOM_2010_new3['Temp_norm'] = (PlankTOM_2010_new3['Temp'] - Temp_mean)/Temp_std

# PlankTOM_2010_new3['MLD_log'] = np.log(PlankTOM_2010_new3['MLD'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['MLD_norm'] = (PlankTOM_2010_new3['MLD_log'] - MLD_mean)/MLD_std

# PlankTOM_2010_new3['O2_norm'] = (PlankTOM_2010_new3['O2'] - O2_mean)/O2_std

# PlankTOM_2010_new3['NO3_norm'] = (PlankTOM_2010_new3['NO3'] - NO3_mean)/NO3_std

# PlankTOM_2010_new3['PO4_norm'] = (PlankTOM_2010_new3['PO4'] - PO4_mean)/PO4_std

# PlankTOM_2010_new3['Si_norm'] = (PlankTOM_2010_new3['Si'] - Si_mean)/Si_std

# PlankTOM_2010_new3['CHL_log'] = np.log(PlankTOM_2010_new3['CHL'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['CHL_norm'] = (PlankTOM_2010_new3['CHL_log'] - CHL_mean)/CHL_std

# PlankTOM_2010_new3['CHL_back_log'] = np.log(PlankTOM_2010_new3['CHL_back'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['CHL_back_norm'] = (PlankTOM_2010_new3['CHL_back_log'] - CHL_back_mean)/CHL_back_std

# PlankTOM_2010_new3['BAC_log'] = np.log(PlankTOM_2010_new3['BAC'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['BAC_norm'] = (PlankTOM_2010_new3['BAC_log'] - BAC_mean)/BAC_std

# PlankTOM_2010_new3['MES_log'] = np.log(PlankTOM_2010_new3['MES'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['MES_norm'] = (PlankTOM_2010_new3['MES_log'] - MES_mean)/MES_std

# PlankTOM_2010_new3['PTE_log'] = np.log(PlankTOM_2010_new3['PTE'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['PTE_norm'] = (PlankTOM_2010_new3['PTE_log'] - PTE_mean)/PTE_std

# PlankTOM_2010_new3['DIA_log'] = np.log(PlankTOM_2010_new3['DIA'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['DIA_norm'] = (PlankTOM_2010_new3['DIA_log'] - DIA_mean)/DIA_std

# PlankTOM_2010_new3['COC_log'] = np.log(PlankTOM_2010_new3['COC'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['COC_norm'] = (PlankTOM_2010_new3['COC_log'] - COC_mean)/COC_std

# PlankTOM_2010_new3['PIC_log'] = np.log(PlankTOM_2010_new3['PIC'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['PIC_norm'] = (PlankTOM_2010_new3['PIC_log'] - PIC_mean)/PIC_std

# PlankTOM_2010_new3['PHA_log'] = np.log(PlankTOM_2010_new3['PHA'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['PHA_norm'] = (PlankTOM_2010_new3['PHA_log'] - PHA_mean)/PHA_std

# PlankTOM_2010_new3['GEL_log'] = np.log(PlankTOM_2010_new3['GEL'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['GEL_norm'] = (PlankTOM_2010_new3['GEL_log'] - GEL_mean)/GEL_std

# PlankTOM_2010_new3['PRO_log'] = np.log(PlankTOM_2010_new3['PRO'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['PRO_norm'] = (PlankTOM_2010_new3['PRO_log'] - PRO_mean)/PRO_std

# PlankTOM_2010_new3['MAC_log'] = np.log(PlankTOM_2010_new3['MAC'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['MAC_norm'] = (PlankTOM_2010_new3['MAC_log'] - MAC_mean)/MAC_std

# PlankTOM_2010_new3['MIX_log'] = np.log(PlankTOM_2010_new3['MIX'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['MIX_norm'] = (PlankTOM_2010_new3['MIX_log'] - MIX_mean)/MIX_std

# PlankTOM_2010_new3['FIX_log'] = np.log(PlankTOM_2010_new3['FIX'])
# PlankTOM_2010_new3 = PlankTOM_2010_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2010_new3['FIX_norm'] = (PlankTOM_2010_new3['FIX_log'] - FIX_mean)/FIX_std

# PlankTOM_2010_new3['O2_mean_norm'] = (PlankTOM_2010_new3['O2_mean'] - O2_m_mean)/O2_m_std

# PlankTOM_2010_new3['NO3_mean_norm'] = (PlankTOM_2010_new3['NO3_mean'] - NO3_m_mean)/NO3_m_std

# PlankTOM_2010_new3['PO4_mean_norm'] = (PlankTOM_2010_new3['PO4_mean'] - PO4_m_mean)/PO4_m_std

# PlankTOM_2010_new3['Si_mean_norm'] = (PlankTOM_2010_new3['Si_mean'] - Si_m_mean)/Si_m_std

# PlankTOM_2010_new3['CHL_mean_norm'] = (PlankTOM_2010_new3['CHL_mean'] - CHL_m_mean)/CHL_m_std

# PlankTOM_2010_new3['CHL_back_mean_norm'] = (PlankTOM_2010_new3['CHL_back_mean'] - CHL_back_m_mean)/CHL_back_m_std

# PlankTOM_2010_new3['BAC_mean_norm'] = (PlankTOM_2010_new3['BAC_mean'] - BAC_m_mean)/BAC_m_std

# PlankTOM_2010_new3['MES_mean_norm'] = (PlankTOM_2010_new3['MES_mean'] - MES_m_mean)/MES_m_std

# PlankTOM_2010_new3['PTE_mean_norm'] = (PlankTOM_2010_new3['PTE_mean'] - PTE_m_mean)/PTE_m_std

# PlankTOM_2010_new3['DIA_mean_norm'] = (PlankTOM_2010_new3['DIA_mean'] - DIA_m_mean)/DIA_m_std

# PlankTOM_2010_new3['COC_mean_norm'] = (PlankTOM_2010_new3['COC_mean'] - COC_m_mean)/COC_m_std

# PlankTOM_2010_new3['PIC_mean_norm'] = (PlankTOM_2010_new3['PIC_mean'] - PIC_m_mean)/PIC_m_std

# PlankTOM_2010_new3['PHA_mean_norm'] = (PlankTOM_2010_new3['PHA_mean'] - PHA_m_mean)/PHA_m_std

# PlankTOM_2010_new3['GEL_mean_norm'] = (PlankTOM_2010_new3['GEL_mean'] - GEL_m_mean)/GEL_m_std

# PlankTOM_2010_new3['PRO_mean_norm'] = (PlankTOM_2010_new3['PRO_mean'] - PRO_m_mean)/PRO_m_std

# PlankTOM_2010_new3['MAC_mean_norm'] = (PlankTOM_2010_new3['MAC_mean'] - MAC_m_mean)/MAC_m_std
                                       
# PlankTOM_2010_new3['MIX_mean_norm'] = (PlankTOM_2010_new3['MIX_mean'] - MIX_m_mean)/MIX_m_std

# PlankTOM_2010_new3['FIX_mean_norm'] = (PlankTOM_2010_new3['FIX_mean'] - FIX_m_mean)/FIX_m_std
# Out:
# /Users/annasommer/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# PlankTOM_2011_new3['POC_log'] = np.log(PlankTOM_2011_new3['POC'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['POC_norm'] = (PlankTOM_2011_new3['POC_log'] - POC_mean)/POC_std

# PlankTOM_2011_new3['GOC_log'] = np.log(PlankTOM_2011_new3['GOC'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['GOC_norm'] = (PlankTOM_2011_new3['GOC_log'] - GOC_mean)/GOC_std

# PlankTOM_2011_new3['depth_log'] = np.log(PlankTOM_2011_new3['depth'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['depth_norm'] = (PlankTOM_2011_new3['depth_log'] - depth_mean)/depth_std

# PlankTOM_2011_new3['Temp_norm'] = (PlankTOM_2011_new3['Temp'] - Temp_mean)/Temp_std

# PlankTOM_2011_new3['MLD_log'] = np.log(PlankTOM_2011_new3['MLD'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['MLD_norm'] = (PlankTOM_2011_new3['MLD_log'] - MLD_mean)/MLD_std

# PlankTOM_2011_new3['O2_norm'] = (PlankTOM_2011_new3['O2'] - O2_mean)/O2_std

# PlankTOM_2011_new3['NO3_norm'] = (PlankTOM_2011_new3['NO3'] - NO3_mean)/NO3_std

# PlankTOM_2011_new3['PO4_norm'] = (PlankTOM_2011_new3['PO4'] - PO4_mean)/PO4_std

# PlankTOM_2011_new3['Si_norm'] = (PlankTOM_2011_new3['Si'] - Si_mean)/Si_std

# PlankTOM_2011_new3['CHL_log'] = np.log(PlankTOM_2011_new3['CHL'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['CHL_norm'] = (PlankTOM_2011_new3['CHL_log'] - CHL_mean)/CHL_std

# PlankTOM_2011_new3['CHL_back_log'] = np.log(PlankTOM_2011_new3['CHL_back'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['CHL_back_norm'] = (PlankTOM_2011_new3['CHL_back_log'] - CHL_back_mean)/CHL_back_std

# PlankTOM_2011_new3['BAC_log'] = np.log(PlankTOM_2011_new3['BAC'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['BAC_norm'] = (PlankTOM_2011_new3['BAC_log'] - BAC_mean)/BAC_std

# PlankTOM_2011_new3['MES_log'] = np.log(PlankTOM_2011_new3['MES'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['MES_norm'] = (PlankTOM_2011_new3['MES_log'] - MES_mean)/MES_std

# PlankTOM_2011_new3['PTE_log'] = np.log(PlankTOM_2011_new3['PTE'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['PTE_norm'] = (PlankTOM_2011_new3['PTE_log'] - PTE_mean)/PTE_std

# PlankTOM_2011_new3['DIA_log'] = np.log(PlankTOM_2011_new3['DIA'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['DIA_norm'] = (PlankTOM_2011_new3['DIA_log'] - DIA_mean)/DIA_std

# PlankTOM_2011_new3['COC_log'] = np.log(PlankTOM_2011_new3['COC'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['COC_norm'] = (PlankTOM_2011_new3['COC_log'] - COC_mean)/COC_std

# PlankTOM_2011_new3['PIC_log'] = np.log(PlankTOM_2011_new3['PIC'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['PIC_norm'] = (PlankTOM_2011_new3['PIC_log'] - PIC_mean)/PIC_std

# PlankTOM_2011_new3['PHA_log'] = np.log(PlankTOM_2011_new3['PHA'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['PHA_norm'] = (PlankTOM_2011_new3['PHA_log'] - PHA_mean)/PHA_std

# PlankTOM_2011_new3['GEL_log'] = np.log(PlankTOM_2011_new3['GEL'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['GEL_norm'] = (PlankTOM_2011_new3['GEL_log'] - GEL_mean)/GEL_std

# PlankTOM_2011_new3['PRO_log'] = np.log(PlankTOM_2011_new3['PRO'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['PRO_norm'] = (PlankTOM_2011_new3['PRO_log'] - PRO_mean)/PRO_std

# PlankTOM_2011_new3['MAC_log'] = np.log(PlankTOM_2011_new3['MAC'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['MAC_norm'] = (PlankTOM_2011_new3['MAC_log'] - MAC_mean)/MAC_std

# PlankTOM_2011_new3['MIX_log'] = np.log(PlankTOM_2011_new3['MIX'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['MIX_norm'] = (PlankTOM_2011_new3['MIX_log'] - MIX_mean)/MIX_std

# PlankTOM_2011_new3['FIX_log'] = np.log(PlankTOM_2011_new3['FIX'])
# PlankTOM_2011_new3 = PlankTOM_2011_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2011_new3['FIX_norm'] = (PlankTOM_2011_new3['FIX_log'] - FIX_mean)/FIX_std

# PlankTOM_2011_new3['O2_mean_norm'] = (PlankTOM_2011_new3['O2_mean'] - O2_m_mean)/O2_m_std

# PlankTOM_2011_new3['NO3_mean_norm'] = (PlankTOM_2011_new3['NO3_mean'] - NO3_m_mean)/NO3_m_std

# PlankTOM_2011_new3['PO4_mean_norm'] = (PlankTOM_2011_new3['PO4_mean'] - PO4_m_mean)/PO4_m_std

# PlankTOM_2011_new3['Si_mean_norm'] = (PlankTOM_2011_new3['Si_mean'] - Si_m_mean)/Si_m_std

# PlankTOM_2011_new3['CHL_mean_norm'] = (PlankTOM_2011_new3['CHL_mean'] - CHL_m_mean)/CHL_m_std

# PlankTOM_2011_new3['CHL_back_mean_norm'] = (PlankTOM_2011_new3['CHL_back_mean'] - CHL_back_m_mean)/CHL_back_m_std

# PlankTOM_2011_new3['BAC_mean_norm'] = (PlankTOM_2011_new3['BAC_mean'] - BAC_m_mean)/BAC_m_std

# PlankTOM_2011_new3['MES_mean_norm'] = (PlankTOM_2011_new3['MES_mean'] - MES_m_mean)/MES_m_std

# PlankTOM_2011_new3['PTE_mean_norm'] = (PlankTOM_2011_new3['PTE_mean'] - PTE_m_mean)/PTE_m_std

# PlankTOM_2011_new3['DIA_mean_norm'] = (PlankTOM_2011_new3['DIA_mean'] - DIA_m_mean)/DIA_m_std

# PlankTOM_2011_new3['COC_mean_norm'] = (PlankTOM_2011_new3['COC_mean'] - COC_m_mean)/COC_m_std

# PlankTOM_2011_new3['PIC_mean_norm'] = (PlankTOM_2011_new3['PIC_mean'] - PIC_m_mean)/PIC_m_std

# PlankTOM_2011_new3['PHA_mean_norm'] = (PlankTOM_2011_new3['PHA_mean'] - PHA_m_mean)/PHA_m_std

# PlankTOM_2011_new3['GEL_mean_norm'] = (PlankTOM_2011_new3['GEL_mean'] - GEL_m_mean)/GEL_m_std

# PlankTOM_2011_new3['PRO_mean_norm'] = (PlankTOM_2011_new3['PRO_mean'] - PRO_m_mean)/PRO_m_std

# PlankTOM_2011_new3['MAC_mean_norm'] = (PlankTOM_2011_new3['MAC_mean'] - MAC_m_mean)/MAC_m_std
                                       
# PlankTOM_2011_new3['MIX_mean_norm'] = (PlankTOM_2011_new3['MIX_mean'] - MIX_m_mean)/MIX_m_std

# PlankTOM_2011_new3['FIX_mean_norm'] = (PlankTOM_2011_new3['FIX_mean'] - FIX_m_mean)/FIX_m_std
# Out:
# /Users/annasommer/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# PlankTOM_2012_new3['POC_log'] = np.log(PlankTOM_2012_new3['POC'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['POC_norm'] = (PlankTOM_2012_new3['POC_log'] - POC_mean)/POC_std

# PlankTOM_2012_new3['GOC_log'] = np.log(PlankTOM_2012_new3['GOC'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['GOC_norm'] = (PlankTOM_2012_new3['GOC_log'] - GOC_mean)/GOC_std

# PlankTOM_2012_new3['depth_log'] = np.log(PlankTOM_2012_new3['depth'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['depth_norm'] = (PlankTOM_2012_new3['depth_log'] - depth_mean)/depth_std

# PlankTOM_2012_new3['Temp_norm'] = (PlankTOM_2012_new3['Temp'] - Temp_mean)/Temp_std

# PlankTOM_2012_new3['MLD_log'] = np.log(PlankTOM_2012_new3['MLD'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['MLD_norm'] = (PlankTOM_2012_new3['MLD_log'] - MLD_mean)/MLD_std

# PlankTOM_2012_new3['O2_norm'] = (PlankTOM_2012_new3['O2'] - O2_mean)/O2_std

# PlankTOM_2012_new3['NO3_norm'] = (PlankTOM_2012_new3['NO3'] - NO3_mean)/NO3_std

# PlankTOM_2012_new3['PO4_norm'] = (PlankTOM_2012_new3['PO4'] - PO4_mean)/PO4_std

# PlankTOM_2012_new3['Si_norm'] = (PlankTOM_2012_new3['Si'] - Si_mean)/Si_std

# PlankTOM_2012_new3['CHL_log'] = np.log(PlankTOM_2012_new3['CHL'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['CHL_norm'] = (PlankTOM_2012_new3['CHL_log'] - CHL_mean)/CHL_std

# PlankTOM_2012_new3['CHL_back_log'] = np.log(PlankTOM_2012_new3['CHL_back'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['CHL_back_norm'] = (PlankTOM_2012_new3['CHL_back_log'] - CHL_back_mean)/CHL_back_std

# PlankTOM_2012_new3['BAC_log'] = np.log(PlankTOM_2012_new3['BAC'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['BAC_norm'] = (PlankTOM_2012_new3['BAC_log'] - BAC_mean)/BAC_std

# PlankTOM_2012_new3['MES_log'] = np.log(PlankTOM_2012_new3['MES'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['MES_norm'] = (PlankTOM_2012_new3['MES_log'] - MES_mean)/MES_std

# PlankTOM_2012_new3['PTE_log'] = np.log(PlankTOM_2012_new3['PTE'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['PTE_norm'] = (PlankTOM_2012_new3['PTE_log'] - PTE_mean)/PTE_std

# PlankTOM_2012_new3['DIA_log'] = np.log(PlankTOM_2012_new3['DIA'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['DIA_norm'] = (PlankTOM_2012_new3['DIA_log'] - DIA_mean)/DIA_std

# PlankTOM_2012_new3['COC_log'] = np.log(PlankTOM_2012_new3['COC'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['COC_norm'] = (PlankTOM_2012_new3['COC_log'] - COC_mean)/COC_std

# PlankTOM_2012_new3['PIC_log'] = np.log(PlankTOM_2012_new3['PIC'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['PIC_norm'] = (PlankTOM_2012_new3['PIC_log'] - PIC_mean)/PIC_std

# PlankTOM_2012_new3['PHA_log'] = np.log(PlankTOM_2012_new3['PHA'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['PHA_norm'] = (PlankTOM_2012_new3['PHA_log'] - PHA_mean)/PHA_std

# PlankTOM_2012_new3['GEL_log'] = np.log(PlankTOM_2012_new3['GEL'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['GEL_norm'] = (PlankTOM_2012_new3['GEL_log'] - GEL_mean)/GEL_std

# PlankTOM_2012_new3['PRO_log'] = np.log(PlankTOM_2012_new3['PRO'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['PRO_norm'] = (PlankTOM_2012_new3['PRO_log'] - PRO_mean)/PRO_std

# PlankTOM_2012_new3['MAC_log'] = np.log(PlankTOM_2012_new3['MAC'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['MAC_norm'] = (PlankTOM_2012_new3['MAC_log'] - MAC_mean)/MAC_std

# PlankTOM_2012_new3['MIX_log'] = np.log(PlankTOM_2012_new3['MIX'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['MIX_norm'] = (PlankTOM_2012_new3['MIX_log'] - MIX_mean)/MIX_std

# PlankTOM_2012_new3['FIX_log'] = np.log(PlankTOM_2012_new3['FIX'])
# PlankTOM_2012_new3 = PlankTOM_2012_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2012_new3['FIX_norm'] = (PlankTOM_2012_new3['FIX_log'] - FIX_mean)/FIX_std

# PlankTOM_2012_new3['O2_mean_norm'] = (PlankTOM_2012_new3['O2_mean'] - O2_m_mean)/O2_m_std

# PlankTOM_2012_new3['NO3_mean_norm'] = (PlankTOM_2012_new3['NO3_mean'] - NO3_m_mean)/NO3_m_std

# PlankTOM_2012_new3['PO4_mean_norm'] = (PlankTOM_2012_new3['PO4_mean'] - PO4_m_mean)/PO4_m_std

# PlankTOM_2012_new3['Si_mean_norm'] = (PlankTOM_2012_new3['Si_mean'] - Si_m_mean)/Si_m_std

# PlankTOM_2012_new3['CHL_mean_norm'] = (PlankTOM_2012_new3['CHL_mean'] - CHL_m_mean)/CHL_m_std

# PlankTOM_2012_new3['CHL_back_mean_norm'] = (PlankTOM_2012_new3['CHL_back_mean'] - CHL_back_m_mean)/CHL_back_m_std

# PlankTOM_2012_new3['BAC_mean_norm'] = (PlankTOM_2012_new3['BAC_mean'] - BAC_m_mean)/BAC_m_std

# PlankTOM_2012_new3['MES_mean_norm'] = (PlankTOM_2012_new3['MES_mean'] - MES_m_mean)/MES_m_std

# PlankTOM_2012_new3['PTE_mean_norm'] = (PlankTOM_2012_new3['PTE_mean'] - PTE_m_mean)/PTE_m_std

# PlankTOM_2012_new3['DIA_mean_norm'] = (PlankTOM_2012_new3['DIA_mean'] - DIA_m_mean)/DIA_m_std

# PlankTOM_2012_new3['COC_mean_norm'] = (PlankTOM_2012_new3['COC_mean'] - COC_m_mean)/COC_m_std

# PlankTOM_2012_new3['PIC_mean_norm'] = (PlankTOM_2012_new3['PIC_mean'] - PIC_m_mean)/PIC_m_std

# PlankTOM_2012_new3['PHA_mean_norm'] = (PlankTOM_2012_new3['PHA_mean'] - PHA_m_mean)/PHA_m_std

# PlankTOM_2012_new3['GEL_mean_norm'] = (PlankTOM_2012_new3['GEL_mean'] - GEL_m_mean)/GEL_m_std

# PlankTOM_2012_new3['PRO_mean_norm'] = (PlankTOM_2012_new3['PRO_mean'] - PRO_m_mean)/PRO_m_std

# PlankTOM_2012_new3['MAC_mean_norm'] = (PlankTOM_2012_new3['MAC_mean'] - MAC_m_mean)/MAC_m_std
                                       
# PlankTOM_2012_new3['MIX_mean_norm'] = (PlankTOM_2012_new3['MIX_mean'] - MIX_m_mean)/MIX_m_std

# PlankTOM_2012_new3['FIX_mean_norm'] = (PlankTOM_2012_new3['FIX_mean'] - FIX_m_mean)/FIX_m_std
# Out:
# /Users/annasommer/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# PlankTOM_2013_new3['POC_log'] = np.log(PlankTOM_2013_new3['POC'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['POC_norm'] = (PlankTOM_2013_new3['POC_log'] - POC_mean)/POC_std

# PlankTOM_2013_new3['GOC_log'] = np.log(PlankTOM_2013_new3['GOC'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['GOC_norm'] = (PlankTOM_2013_new3['GOC_log'] - GOC_mean)/GOC_std

# PlankTOM_2013_new3['depth_log'] = np.log(PlankTOM_2013_new3['depth'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['depth_norm'] = (PlankTOM_2013_new3['depth_log'] - depth_mean)/depth_std

# PlankTOM_2013_new3['Temp_norm'] = (PlankTOM_2013_new3['Temp'] - Temp_mean)/Temp_std

# PlankTOM_2013_new3['MLD_log'] = np.log(PlankTOM_2013_new3['MLD'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['MLD_norm'] = (PlankTOM_2013_new3['MLD_log'] - MLD_mean)/MLD_std

# PlankTOM_2013_new3['O2_norm'] = (PlankTOM_2013_new3['O2'] - O2_mean)/O2_std

# PlankTOM_2013_new3['NO3_norm'] = (PlankTOM_2013_new3['NO3'] - NO3_mean)/NO3_std

# PlankTOM_2013_new3['PO4_norm'] = (PlankTOM_2013_new3['PO4'] - PO4_mean)/PO4_std

# PlankTOM_2013_new3['Si_norm'] = (PlankTOM_2013_new3['Si'] - Si_mean)/Si_std

# PlankTOM_2013_new3['CHL_log'] = np.log(PlankTOM_2013_new3['CHL'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['CHL_norm'] = (PlankTOM_2013_new3['CHL_log'] - CHL_mean)/CHL_std

# PlankTOM_2013_new3['CHL_back_log'] = np.log(PlankTOM_2013_new3['CHL_back'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['CHL_back_norm'] = (PlankTOM_2013_new3['CHL_back_log'] - CHL_back_mean)/CHL_back_std

# PlankTOM_2013_new3['BAC_log'] = np.log(PlankTOM_2013_new3['BAC'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['BAC_norm'] = (PlankTOM_2013_new3['BAC_log'] - BAC_mean)/BAC_std

# PlankTOM_2013_new3['MES_log'] = np.log(PlankTOM_2013_new3['MES'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['MES_norm'] = (PlankTOM_2013_new3['MES_log'] - MES_mean)/MES_std

# PlankTOM_2013_new3['PTE_log'] = np.log(PlankTOM_2013_new3['PTE'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['PTE_norm'] = (PlankTOM_2013_new3['PTE_log'] - PTE_mean)/PTE_std

# PlankTOM_2013_new3['DIA_log'] = np.log(PlankTOM_2013_new3['DIA'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['DIA_norm'] = (PlankTOM_2013_new3['DIA_log'] - DIA_mean)/DIA_std

# PlankTOM_2013_new3['COC_log'] = np.log(PlankTOM_2013_new3['COC'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['COC_norm'] = (PlankTOM_2013_new3['COC_log'] - COC_mean)/COC_std

# PlankTOM_2013_new3['PIC_log'] = np.log(PlankTOM_2013_new3['PIC'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['PIC_norm'] = (PlankTOM_2013_new3['PIC_log'] - PIC_mean)/PIC_std

# PlankTOM_2013_new3['PHA_log'] = np.log(PlankTOM_2013_new3['PHA'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['PHA_norm'] = (PlankTOM_2013_new3['PHA_log'] - PHA_mean)/PHA_std

# PlankTOM_2013_new3['GEL_log'] = np.log(PlankTOM_2013_new3['GEL'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['GEL_norm'] = (PlankTOM_2013_new3['GEL_log'] - GEL_mean)/GEL_std

# PlankTOM_2013_new3['PRO_log'] = np.log(PlankTOM_2013_new3['PRO'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['PRO_norm'] = (PlankTOM_2013_new3['PRO_log'] - PRO_mean)/PRO_std

# PlankTOM_2013_new3['MAC_log'] = np.log(PlankTOM_2013_new3['MAC'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['MAC_norm'] = (PlankTOM_2013_new3['MAC_log'] - MAC_mean)/MAC_std

# PlankTOM_2013_new3['MIX_log'] = np.log(PlankTOM_2013_new3['MIX'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['MIX_norm'] = (PlankTOM_2013_new3['MIX_log'] - MIX_mean)/MIX_std

# PlankTOM_2013_new3['FIX_log'] = np.log(PlankTOM_2013_new3['FIX'])
# PlankTOM_2013_new3 = PlankTOM_2013_new3.replace([np.inf,-np.inf],0.)
# PlankTOM_2013_new3['FIX_norm'] = (PlankTOM_2013_new3['FIX_log'] - FIX_mean)/FIX_std

# PlankTOM_2013_new3['O2_mean_norm'] = (PlankTOM_2013_new3['O2_mean'] - O2_m_mean)/O2_m_std

# PlankTOM_2013_new3['NO3_mean_norm'] = (PlankTOM_2013_new3['NO3_mean'] - NO3_m_mean)/NO3_m_std

# PlankTOM_2013_new3['PO4_mean_norm'] = (PlankTOM_2013_new3['PO4_mean'] - PO4_m_mean)/PO4_m_std

# PlankTOM_2013_new3['Si_mean_norm'] = (PlankTOM_2013_new3['Si_mean'] - Si_m_mean)/Si_m_std

# PlankTOM_2013_new3['CHL_mean_norm'] = (PlankTOM_2013_new3['CHL_mean'] - CHL_m_mean)/CHL_m_std

# PlankTOM_2013_new3['CHL_back_mean_norm'] = (PlankTOM_2013_new3['CHL_back_mean'] - CHL_back_m_mean)/CHL_back_m_std

# PlankTOM_2013_new3['BAC_mean_norm'] = (PlankTOM_2013_new3['BAC_mean'] - BAC_m_mean)/BAC_m_std

# PlankTOM_2013_new3['MES_mean_norm'] = (PlankTOM_2013_new3['MES_mean'] - MES_m_mean)/MES_m_std

# PlankTOM_2013_new3['PTE_mean_norm'] = (PlankTOM_2013_new3['PTE_mean'] - PTE_m_mean)/PTE_m_std

# PlankTOM_2013_new3['DIA_mean_norm'] = (PlankTOM_2013_new3['DIA_mean'] - DIA_m_mean)/DIA_m_std

# PlankTOM_2013_new3['COC_mean_norm'] = (PlankTOM_2013_new3['COC_mean'] - COC_m_mean)/COC_m_std

# PlankTOM_2013_new3['PIC_mean_norm'] = (PlankTOM_2013_new3['PIC_mean'] - PIC_m_mean)/PIC_m_std

# PlankTOM_2013_new3['PHA_mean_norm'] = (PlankTOM_2013_new3['PHA_mean'] - PHA_m_mean)/PHA_m_std

# PlankTOM_2013_new3['GEL_mean_norm'] = (PlankTOM_2013_new3['GEL_mean'] - GEL_m_mean)/GEL_m_std

# PlankTOM_2013_new3['PRO_mean_norm'] = (PlankTOM_2013_new3['PRO_mean'] - PRO_m_mean)/PRO_m_std

# PlankTOM_2013_new3['MAC_mean_norm'] = (PlankTOM_2013_new3['MAC_mean'] - MAC_m_mean)/MAC_m_std
                                    
# PlankTOM_2013_new3['MIX_mean_norm'] = (PlankTOM_2013_new3['MIX_mean'] - MIX_m_mean)/MIX_m_std

# PlankTOM_2013_new3['FIX_mean_norm'] = (PlankTOM_2013_new3['FIX_mean'] - FIX_m_mean)/FIX_m_std
# Out:
# /Users/annasommer/opt/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#write results in .csv file
All_Data_final.to_csv('Data_from_PlankTOM/Data_Obs_Pos_14122021.csv') 
All_Data_IV_Pl_new.to_csv('Data_from_PlankTOM/Data_IV_14122021.csv')
PlankTOM_2009_new3.to_csv('Data_from_PlankTOM/Data_PlankTOM2009_07102021.csv')
PlankTOM_2010_new3.to_csv('Data_from_PlankTOM/Data_PlankTOM2010_07102021.csv')
PlankTOM_2011_new3.to_csv('Data_from_PlankTOM/Data_PlankTOM2011_07102021.csv')
PlankTOM_2012_new3.to_csv('Data_from_PlankTOM/Data_PlankTOM2012_07102021.csv')
PlankTOM_2013_new3.to_csv('Data_from_PlankTOM/Data_PlankTOM2013_07102021.csv')
